# %%
from def_conv_crs_2h import*
from def_conv_crs_1h import*
import matplotlib.pyplot as plt

# %%
z2 = linspace(0.22,0.7,50)

# %%
f_prm=arange(0.,18.,1.)
f_prm[0] =0.44915129
f_prm[1] = -0.5825860#par[0]  #do
f_prm[2] = -0.997297   #par[0]      #st
f_prm[3] = -0.22059532  #par[0]      #upb
f_prm[4] = f_prm[3] #par[0]      #dob
f_prm[5] = f_prm[3] # par[0]      #stb
#¯¯¯¯¯¯
f_prm[6] = 0 #par[0]      #aup
f_prm[7] = 0 #par[0]      #ado
f_prm[8] = 2.01893176 # par[0]      #ast
f_prm[9] = 0# par[0]      #aupb
f_prm[10] = f_prm[9] #par[0]      #adob
f_prm[11] = f_prm[9] #par[0]      #astb
#¯#¯¯¯¯¯¯¯
f_prm[12] = 2.05009352 #par[0]      #bup
f_prm[13] = 0 #par[0]      #bdo
f_prm[14] = 0# par[0]      #bst
f_prm[15] =  0.59716446 #par[0]      #bupb
f_prm[16] = f_prm[15] #par[0]      #bdob
f_prm[17] = f_prm[15] # par[0]      #bstb
wdt_pol=0.0661212

# %%
pr = polarization(0.3)
pr.g_k ='old'
tr = polarization(0.3)
tr.g_k='exp'

# %%
rat1=zeros(len(z2))
rat2=zeros(len(z2))
i=0
for z2s in z2:
    rat1[i] = pr.ratio('lbd','pi+',0.6,z2s,f_prm,wdt_pol)
    rat2[i] = tr.ratio('lbd','pi+',0.6,z2s,f_prm,wdt_pol)
    i+=1

# %%
plot(z2,rat1,label='quadr')
plot(z2,rat2,label='exp')
legend()
show()

# %%
fr = polarization_1h()
gr = polarization_1h()
hr = polarization_1h()
jr = polarization_1h()

# %%
pts = linspace(0.08,1.1,500)
rat1h=zeros(len(pts))
rat2h=zeros(len(pts))
gr.g_k='exp'
i=0
for pt in pts:
    
    rat1h[i]=fr.ratio('lbd',0.35,pt,f_prm,wdt_pol)
    rat2h[i]=gr.ratio('lbd',0.35,pt,f_prm,wdt_pol)
    i+=1

plot(pts,rat1h,label='new')
plot(pts,rat2h,label='exp')
legend()
show()

# %%
fr.g_k = 'exp'
gr.g_k = 'new'
hr.g_k = 'll'
jr.g_k = 'old'

# %%
pts = linspace(0.08,1.1,500)
rat1h=zeros(len(pts))
rat2h=zeros(len(pts))
rat3h=zeros(len(pts))
rat4h=zeros(len(pts))
i=0
for pt in pts:
    
    rat1h[i]=fr.ratio('lbd',0.35,pt,f_prm,wdt_pol)
    rat2h[i]=gr.ratio('lbd',0.35,pt,f_prm,wdt_pol)
    rat3h[i]=hr.ratio('lbd',0.35,pt,f_prm,wdt_pol)
    rat4h[i]=jr.ratio('lbd',0.35,pt,f_prm,wdt_pol)
    i+=1

plot(pts,rat1h,label='exp')
plot(pts,rat2h,label='new')
plot(pts,rat3h,label='ll')
plot(pts,rat4h,label='old')
legend()
show()

# %%
print(fr.g_k)  ;print(gr.g_k)
# Out:
# exp
# new
