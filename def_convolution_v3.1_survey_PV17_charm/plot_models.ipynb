# %%
# -*- coding: utf-8 -*-
from pylab import*
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import*
from scipy import special
from def_crs import*
from model_fct import*
from g_funct import*
from FBT import FBT 
from model_fct import*
from Sudakov.sudakov_factor import*
from Sudakov.evolve import evolve, sng
from scipy import special
#plt.rcParams['text.usetex'] = True
# Out:
# /home/zackmrc/Documenti/git_project/lambda_fit/def_convolution_v3.1_survey_PV17

# %%
scl =Soft(0)
scl.bmax
bts = linspace(0.001,6,1000)

# %%
zh = 0.45
zh1 = 0.45
zh2=0.45
had2='pi+'
bts = linspace(0.001,4.5,1000)

ln_wd = 6

plt.figure(figsize=(11, 9))
plt.plot(bts,scl.g_K(bts),linestyle='--',label = 'AFGR / SIYY',linewidth=ln_wd)
plt.plot(bts,scl.g_K_ll_lgm(bts,had2,zh1,zh2),linestyle='dashdot',label = 'Logarithmic',linewidth=ln_wd)
#plt.plot(bts,scl.g_K_exp_lgm(bts,had2,zh1,zh2),label = 'exp (3)',linewidth=3)
plt.plot(bts,scl.g_K_new_lgm(bts,had2,zh1,zh2),linestyle='dotted',label = 'Quadratic',linewidth=ln_wd)
#plt.plot(bts,scl.g_K_bac_lgm(bts,had2,zh1,zh2),linestyle=(0, (3, 1, 1, 1, 1, 1)),label='PV17 (5)',linewidth=3)
plt.plot(bts,scl.g_K_blny(bts,had2,zh1,zh2),linestyle=(0, (3, 1, 1, 1, 1, 1)),label='BLNY',linewidth=ln_wd,color='r')
#
#
plt.xlabel('$b_T$ $({GeV}^{-1})$',size=30)
#plt.xlabel('\\alpha')
plt.ylabel('$e^{-g_K(b_T)}$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
#plt.ylabel(r"\bf{phase field} $\phi$", fontsize=20)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=1, prop={'size': 25})
plt.savefig('gk_mod.pdf')
plt.savefig('gk_mod.png')

# %%
zh = 0.45
zh1 = 0.45
zh2=0.45
had2='pi+'
bts = linspace(0.001,4.5,1000)

ln_wd = 6

plt.figure(figsize=(11, 9))
plt.plot(bts,scl.g_K(bts),linestyle='--',label = 'AFGR / SIYY',linewidth=ln_wd)
plt.plot(bts,scl.g_K_ll_lgm(bts,had2,zh1,zh2),linestyle='dashdot',label = 'Logarithmic',linewidth=ln_wd)
#plt.plot(bts,scl.g_K_exp_lgm(bts,had2,zh1,zh2),label = 'exp (3)',linewidth=3)
plt.plot(bts,scl.g_K_new_lgm(bts,had2,zh1,zh2),linestyle='dotted',label = 'Quadratic',linewidth=ln_wd)
plt.plot(bts,scl.g_K_bac_lgm(bts,had2,zh1,zh2),linestyle=(0, (3, 1, 1, 1, 1, 1)),label='PV17 (5)',linewidth=ln_wd,color='purple')
plt.plot(bts,scl.g_K_blny(bts,had2,zh1,zh2),linestyle=(0, (3, 1, 1, 1, 1, 1)),label='BLNY',linewidth=ln_wd,color='r')
#
#
plt.xlabel('$b_T$ $({GeV}^{-1})$',size=30)
#plt.xlabel('\\alpha')
plt.ylabel('$e^{-g_K(b_T)}$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
#plt.ylabel(r"\bf{phase field} $\phi$", fontsize=20)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=1, prop={'size': 25})
plt.savefig('gk_mod_2.pdf')
plt.savefig('gk_mod_2.png')

# %%
mdl = model_bt()
zh=0.5
mdl.bmin = 0
plt.figure(figsize=(10, 9))
#ln_wd = 5
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD_bstar(bts,2,zh,1.),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=2$, $m=1$ GeV',)
plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=ln_wd,label='Gaussian $<p^2_{\perp}>=0.2$ ${GeV}^2$')
#plt.plot(bts,mdl.MD(bts,3,.35),linestyle='dashdot',linewidth=3,label='Power Law $p=3$, $m=0.35$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.066),linewidth=3,label='Gaussian $wdt=0.066$')

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$ $({GeV}^{-1})$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=1, prop={'size': 20})
plt.savefig('unp_models.pdf')
plt.savefig('unp_models.png')

# %%
mdl = model_bt()
zh=0.5
mdl.bmin = 0
plt.figure(figsize=(12, 9))
#ln_wd = 5
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD_bstar(bts,2,zh,1.),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=2$, $m=1$ GeV',)
plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=ln_wd,label='Gaussian $<p^2_{\perp}>=0.2$ ${GeV}^2$')
plt.plot(bts,mdl.MD_pv17(bts,zh),linewidth=ln_wd,linestyle='dotted',label='PV17 mod.')

#plt.plot(bts,mdl.MD(bts,3,.35),linestyle='dashdot',linewidth=3,label='Power Law $p=3$, $m=0.35$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.066),linewidth=3,label='Gaussian $wdt=0.066$')

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$ $({GeV}^{-1})$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=1, prop={'size': 20})
plt.savefig('unp_models_2.pdf')
plt.savefig('unp_models_2.png')

# %%
mdl = model_bt()
mdl.bmin = 0
zh=0.5

ln_wd = 5
plt.figure(figsize=(10, 9))

#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
#plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law $p=2$, $m=1$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
plt.plot(bts,mdl.MD_bstar(bts,3,zh,.35),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=3$, $m=0.35$ GeV')
plt.plot(bts,mdl.MD_gauss(bts,zh,0.066),linewidth=ln_wd,label='Gaussian $<p^2_{\perp}>=0.066$ ${GeV}^2$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.103),linewidth=ln_wd,label='Gaussian $<p^2_{\perp}>=0.066$ ${GeV}^2$')

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$ $({GeV}^{-1})$',size=30)
plt.ylabel('$M^{\perp}_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=3, prop={'size': 25})
plt.savefig('pol_models.pdf')
plt.savefig('pol_models.png')

# %%
mdl = model_bt()
mdl.bmin = 0
zh=0.5

ln_wd = 5
plt.figure(figsize=(12, 9))

#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
#plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law $p=2$, $m=1$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
plt.plot(bts,mdl.MD_bstar(bts,3,zh,.35),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=3$, $m=0.35$ GeV')
plt.plot(bts,mdl.MD_gauss(bts,zh,0.066),linewidth=ln_wd,label='Gaussian $<p^2_{\perp}>=0.066$ ${GeV}^2$')
plt.plot(bts,mdl.MD_gauss(bts,zh,0.103),linestyle='dotted',linewidth=ln_wd,label='Gaussian (PV17) $<p^2_{\perp}>=0.103$ ${GeV}^2$')

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$ $({GeV}^{-1})$',size=30)
plt.ylabel('$M^{\perp}_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=3, prop={'size': 25})
plt.savefig('pol_models_2.pdf')
plt.savefig('pol_models_2.png')

# %%
qtmax=10.58
plt.figure(figsize=(10, 9))
plt.plot(bts,special.jv(0,qtmax*bts*0.25),linewidth=3,label='Bessel $J_0$ 0.25')
plt.plot(bts,special.jv(0,qtmax*bts*0.2),linewidth=3,label='Bessel $J_0$ 0.2')
plt.plot(bts,special.jv(0,qtmax*bts*0.3),linewidth=3,label='Bessel $J_0$ 0.3')

#
plt.xlabel('$b_T$',size=30)
plt.ylabel('Bessel ',size=30)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})

# %%
qtmax=10.58
plt.figure(figsize=(10, 9))
plt.plot(bts,special.jv(1,qtmax*bts*0.25),linewidth=3,label='Bessel $J_0$ 0.25')
plt.plot(bts,special.jv(1,qtmax*bts*0.2),linewidth=3,label='Bessel $J_0$ 0.2')
plt.plot(bts,special.jv(1,qtmax*bts*0.3),linewidth=3,label='Bessel $J_0$ 0.3')

#
plt.xlabel('$b_T$',size=30)
plt.ylabel('Bessel ',size=30)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})

# %%
mdl = model_bt()
mdl.bmin=0
x_lbl=30
zh=0.35
bts = linspace(0.0000001,10,5000)
plt.figure(figsize=(10, 8))
pp2=1.352
mss2=0.151

pp1=1.623
mss1=0.48
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD_bstar(bts,pp2,zh,mss2),linestyle='dashdot',linewidth=3,label='Power Law (2) $p='+str(pp2)+ '$, $m='+str(mss2)+ '$' )
plt.plot(bts,mdl.MD_bstar(bts,pp1,zh,mss1),linestyle='dotted',linewidth=3,label='Power Law (2) $p='+str(pp1)+ '$, $m='+str(mss1)+ '$' )

##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.xlim(-0.1,5)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})
plt.text(2., 0.7, r'$z_{h} = '+str(zh)+'$', ha='center',size=x_lbl)
# Out:
# Text(2.0, 0.7, '$z_{h} = 0.35$')

# %%
mdl = model_bt()
mdl.bmin = 0
zh=0.45
plt.figure(figsize=(10, 9))
pp2=1.352
mss2=0.151

#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
#plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law $p=2$, $m=1$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
plt.plot(bts,mdl.MD_bstar(bts,3,zh,.35),linestyle='dashdot',linewidth=3,label='Power Law $p=3$, $m=0.35$')
plt.plot(bts,mdl.MD_bstar(bts,pp2,zh,mss2),linestyle='dashdot',linewidth=3,label='Power Law (2) $p='+str(pp2)+ '$, $m='+str(mss2)+ '$' )
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})

# %%
zs= [0.25,0.35,0.45,0.6]
fig4, axes = plt.subplots(1,4)
ct=1

pp2=1.352
mss2=0.151

pp1=1.623
mss1=0.48


for z1, ax in zip(zs,axes):
    ax=plt.subplot(1,4,ct)
    ax.plot(bts,mdl.MD_bstar(bts,pp2,z1,mss2),linestyle='solid',linewidth=ln_wd,label='$p='+str(pp2)+ '$, $m='+str(mss2)+ '$ GeV' )
    ax.plot(bts,mdl.MD_bstar(bts,pp1,z1,mss1),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp1)+ '$, $m='+str(mss1)+ '$ GeV' )
    #ax.plot(bts,mdl.MD_bstar(bts,pp1,z1,mss1)/mdl.MD_bstar(bts,pp2,z1,mss2),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp1)+ '$, $m='+str(mss1)+ '$' )
    
    
    #plt.xlabel('$b_T$',size=35)
    if ct==1:plt.ylabel('$M^{\perp}_D(b_T)$',size=40)
    plt.ylim(-0.1,1.1)
    plt.xticks(np.arange(min(bts), max(bts)+1, 3.))
    plt.tick_params(axis='x', labelsize=30)
    if ct==1:plt.tick_params(axis='y', labelsize=30)
    if ct==4:plt.legend(loc=1, prop={'size': 15})
    if ct!=1:ax.set_yticklabels([])
    plt.text(7., .7, r'$z_{h} = '+str(z1)+'$', ha='center',size=x_lbl)
    ct+=1
    fig4.text(0.5, 0.1, r'$b_T$ $({GeV}^{-1})$', ha='center',size=x_lbl+0.8)
    #subplots_adjust(top=0.7,bottom=0.0,left=0.052,right=0.99,hspace=0.232,wspace=0.001)
fig4.subplots_adjust(top=0.8,bottom=0.2,left=0.1,right=0.99,hspace=0.2,wspace=0.0)    
#fig4.set_size_inches(25, 10,forward=True)  
fig4.set_size_inches(19.5, 10.5, forward=True)

fig4.savefig('double_model_pwrlw.pdf')    
fig4.savefig('double_model_pwrlw.png')   
#plt.subplot_tool()
#plt.show()

# %%
zs= [0.25,0.35,0.45,0.6]
fig4, axes = plt.subplots(1,4)
ct=1

pp2=1.352
mss2=0.151

pp1=1.623
mss1=0.48


for z1, ax in zip(zs,axes):
    ax=plt.subplot(1,4,ct)
    ax.plot(bts,mdl.MD_bstar(bts,pp2,z1,mss2),linestyle='solid',linewidth=ln_wd,label='$p='+str(pp2)+ '$, $m='+str(mss2)+ '$ GeV' )
    ax.plot(bts,mdl.MD_bstar(bts,pp1,z1,mss1),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp1)+ '$, $m='+str(mss1)+ '$ GeV' )
    ax.plot(bts,mdl.MD_bstar(bts,pp1,z1,mss1)/mdl.MD_bstar(bts,pp2,z1,mss2),linestyle='dashdot',linewidth=ln_wd)
    
    
    #plt.xlabel('$b_T$',size=35)
    if ct==1:plt.ylabel('$M^{\perp}_D(b_T)$',size=40)
    plt.ylim(-0.1,1.1)
    plt.xticks(np.arange(min(bts), max(bts)+1, 3.))
    plt.tick_params(axis='x', labelsize=30)
    if ct==1:plt.tick_params(axis='y', labelsize=30)
    if ct==4:plt.legend(loc=1, prop={'size': 15})
    if ct!=1:ax.set_yticklabels([])
    plt.text(7., .7, r'$z_{h} = '+str(z1)+'$', ha='center',size=x_lbl)
    ct+=1
    fig4.text(0.5, 0.1, r'$b_T$ $({GeV}^{-1})$', ha='center',size=x_lbl+0.8)
    #subplots_adjust(top=0.7,bottom=0.0,left=0.052,right=0.99,hspace=0.232,wspace=0.001)
fig4.subplots_adjust(top=0.8,bottom=0.2,left=0.1,right=0.99,hspace=0.2,wspace=0.0)    
#fig4.set_size_inches(25, 10,forward=True)  
fig4.set_size_inches(19.5, 10.5, forward=True)

#fig4.savefig('double_model_pwrlw.pdf')    
#fig4.savefig('double_model_pwrlw.png')   
#plt.subplot_tool()
#plt.show()

# %%
zs= [0.25,0.35,0.45,0.6]
fig4, axes = plt.subplots(1,4)
ct=1

pp2=1.352
mss2=0.151

pp1=1.623
mss1=0.48


for z1, ax in zip(zs,axes):
    ax=plt.subplot(1,4,ct)
    #ax.plot(bts,mdl.MD_bstar(bts,pp2,z1,mss2),linestyle='solid',linewidth=ln_wd,label='$p='+str(pp2)+ '$, $m='+str(mss2)+ '$' )
    #ax.plot(bts,mdl.MD_bstar(bts,pp1,z1,mss1),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp1)+ '$, $m='+str(mss1)+ '$' )
    ax.plot(bts,mdl.MD_bstar(bts,pp1,z1,mss1)/mdl.MD_bstar(bts,pp2,z1,mss2),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp1)+ '$, $m='+str(mss1)+ '$' )
    
    
    #plt.xlabel('$b_T$',size=35)
    if ct==1:plt.ylabel('$M^{\perp}_D(b_T)$',size=40)
    plt.ylim(-0.1,1.1)
    plt.xticks(np.arange(min(bts), max(bts)+1, 3.))
    plt.tick_params(axis='x', labelsize=30)
    if ct==1:plt.tick_params(axis='y', labelsize=30)
    if ct==2:plt.legend(loc=1, prop={'size': 19})
    if ct!=1:ax.set_yticklabels([])
    plt.text(7., .7, r'$z_{h} = '+str(z1)+'$', ha='center',size=x_lbl)
    ct+=1
    fig4.text(0.5, 0.1, r'$b_T$', ha='center',size=x_lbl+0.8)
    #subplots_adjust(top=0.7,bottom=0.0,left=0.052,right=0.99,hspace=0.232,wspace=0.001)
fig4.subplots_adjust(top=0.8,bottom=0.2,left=0.1,right=0.99,hspace=0.2,wspace=0.0)    
#fig4.set_size_inches(25, 10,forward=True)  
fig4.set_size_inches(19.5, 10.5, forward=True)

fig4.savefig('double_model_pwrlw.pdf')    
#plt.subplot_tool()
#plt.show()

# %%
zs= [0.25,0.35,0.45,0.6]
fig4, axes = plt.subplots(1,4)
ct=1
bts = linspace(0.001,2.5,1000)
pp2=0.04
mss2=0.151

pp1=0.2
mss1=0.48


for z1, ax in zip(zs,axes):
    ax=plt.subplot(1,4,ct)
    ax.plot(bts,mdl.MD_gauss(bts,pp2,z1),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp2)+'$' )
    ax.plot(bts,mdl.MD_gauss(bts,pp1,z1),linestyle='dashdot',linewidth=ln_wd,label='$p='+str(pp1)+'$' )
    #ax.xlim(-0.1,2.)
    
    plt.xlabel('$b_T$',size=35)
    #plt.xlabel('$b_T$',size=35)
    if ct==1:plt.ylabel('$M^{\perp}_D(b_T)$',size=40)
    plt.ylim(-0.1,1.1)
    plt.xlim(-0.1,2)
    plt.xticks(np.arange(min(bts), max(bts)+1, 3.))
    plt.tick_params(axis='x', labelsize=30)
    if ct==1:plt.tick_params(axis='y', labelsize=30)
    if ct==2:plt.legend(loc=1, prop={'size': 19})
    if ct!=1:ax.set_yticklabels([])
    plt.text(4., .7, r'$z_{h} = '+str(z1)+'$', ha='center',size=x_lbl)
    ct+=1
    fig4.text(0.5, 0.1, r'$b_T$', ha='center',size=x_lbl+0.8)
    #subplots_adjust(top=0.7,bottom=0.0,left=0.052,right=0.99,hspace=0.232,wspace=0.001)
fig4.subplots_adjust(top=0.8,bottom=0.2,left=0.1,right=0.99,hspace=0.2,wspace=0.0)    
#fig4.set_size_inches(25, 10,forward=True)  
fig4.set_size_inches(19.5, 10.5, forward=True)

fig4.savefig('double_model_gaussian.pdf')    
#plt.subplot_tool()
#plt.show()

# %%
def power_lw_pt(pts,p,m):
    fact = special.gamma(p)/special.gamma(p-1)/np.pi
    
    fact = fact*m**(2*p-2)
    fact = fact/(pts**2 + m**2)**p
    
    return fact

# %%
plt.figure(figsize=(10, 9))
pts = linspace(0,0.8,100)
#ln_wd = 5
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(pts,power_lw_pt(pts,1.352,0.151),linestyle='solid',linewidth=ln_wd,label='Power Law $p=1.352$, $m=0.151$ GeV',)
plt.plot(pts,power_lw_pt(pts,1.623,0.48),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=1.623$, $m=0.48$ GeV',)

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$p_{\perp}$ (GeV)',size=30)
plt.ylabel('$\widetilde{M}_D(p_{\perp})$',size=30)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=1, prop={'size': 20})
plt.savefig('power_lw_pt.pdf')
plt.savefig('power_lw_pt.png')

# %%
plt.figure(figsize=(10, 9))
pts = linspace(0,0.8,100)
#ln_wd = 5
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(pts,power_lw_pt(pts,1.352,0.151),linestyle='solid',linewidth=ln_wd,label='Power Law $p=1.352$, $m=0.151$',)
plt.plot(pts,power_lw_pt(pts,1.623,0.48),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=1.623$, $m=0.48$',)
plt.plot(pts,power_lw_pt(pts,1.623,0.48)/power_lw_pt(pts,1.352,0.151),linestyle='dashdot',linewidth=ln_wd,label='Power Law $p=1.623$, $m=0.48$',)

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$p_{\perp}$',size=30)
plt.ylabel('$\widetilde{M}_D(p_{\perp})$',size=30)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=25)
plt.tick_params(axis='y', labelsize=25)
plt.legend(loc=1, prop={'size': 20})
plt.savefig('power_lw_pt.pdf')

# %%
pts
# Out:
# array([0.        , 0.00808081, 0.01616162, 0.02424242, 0.03232323,
#        0.04040404, 0.04848485, 0.05656566, 0.06464646, 0.07272727,
#        0.08080808, 0.08888889, 0.0969697 , 0.10505051, 0.11313131,
#        0.12121212, 0.12929293, 0.13737374, 0.14545455, 0.15353535,
#        0.16161616, 0.16969697, 0.17777778, 0.18585859, 0.19393939,
#        0.2020202 , 0.21010101, 0.21818182, 0.22626263, 0.23434343,
#        0.24242424, 0.25050505, 0.25858586, 0.26666667, 0.27474747,
#        0.28282828, 0.29090909, 0.2989899 , 0.30707071, 0.31515152,
#        0.32323232, 0.33131313, 0.33939394, 0.34747475, 0.35555556,
#        0.36363636, 0.37171717, 0.37979798, 0.38787879, 0.3959596 ,
#        0.4040404 , 0.41212121, 0.42020202, 0.42828283, 0.43636364,
#        0.44444444, 0.45252525, 0.46060606, 0.46868687, 0.47676768,
#        0.48484848, 0.49292929, 0.5010101 , 0.50909091, 0.51717172,
#        0.52525253, 0.53333333, 0.54141414, 0.54949495, 0.55757576,
# ...

# %%
coefs = [0.15,0.18,0.2,0.22,0.25,0.27,0.3]
chi_pwrlw = [1.296,1.246,1.205,1.192,1.21,1.237,1.282]
chi_gauss = [1.322,1.197,1.172,1.169,1.192,1.219,1.265]

# %%
plt.figure(figsize=(25, 8))
pts = linspace(0,0.8,100)
#ln_wd = 5
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(coefs,chi_pwrlw,linestyle='dashed',linewidth=ln_wd,alpha=0.7)
plt.plot(coefs,chi_gauss,linestyle='dotted',linewidth=ln_wd,alpha=0.7)
plt.scatter(coefs,chi_pwrlw,s=150,marker='p',color='darkblue',label='Power-Law Model')
plt.scatter(coefs,chi_gauss,s=150,marker='h',color='red',label='Gaussian Model')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$q_{T_{max}}/Q$',size=34)
plt.ylabel('$\chi^2_{dof}$',size=35)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=30)
plt.tick_params(axis='y', labelsize=30)
plt.legend(loc=3, prop={'size': 24})

#plt.savefig('qt_impact.pdf')
#plt.savefig('qt_impact.png')

# %%
coefs = [0.15,0.18,0.2,0.22,0.25,0.27,0.3]
coefs_pv = [0.15,0.18,0.2,0.22,0.25,0.27,0.3,0.32,0.35,0.37,0.4]

chi_pwrlw = [1.296,1.246,1.205,1.192,1.21,1.237,1.282]
chi_gauss = [1.322,1.197,1.172,1.169,1.192,1.219,1.265]
chi_pv = [1.599,1.484,1.393,1.27,1.198,1.178,1.191,1.203,1.241,1.268,1.303]

plt.figure(figsize=(25, 8))
pts = linspace(0,0.8,100)
#ln_wd = 5
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(coefs,chi_pwrlw,linestyle='dashed',linewidth=ln_wd,alpha=0.7)
plt.plot(coefs,chi_gauss,linestyle='dotted',linewidth=ln_wd,alpha=0.7)
plt.plot(coefs_pv,chi_pv,linestyle='dashdot',linewidth=ln_wd,alpha=0.7)
plt.scatter(coefs,chi_pwrlw,s=150,marker='p',color='darkblue',label='Power-Law Mod.')
plt.scatter(coefs,chi_gauss,s=150,marker='h',color='red',label='Gaussian Mod.')
plt.scatter(coefs_pv,chi_pv,s=150,marker='d',color='darkgreen',label='Gaussian Mod. (PV17)')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$q_{T_{max}}/Q$',size=34)
plt.ylabel('$\chi^2_{dof}$',size=35)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=30)
plt.tick_params(axis='y', labelsize=30)
plt.legend(loc=1, prop={'size': 24})

#plt.savefig('qt_impact2.pdf')
#plt.savefig('qt_impact2.png')
