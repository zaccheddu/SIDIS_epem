# %%
# -*- coding: utf-8 -*-
from pylab import*
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import*
from scipy import special
from def_crs import*
from model_fct import*
from g_funct import*
from FBT import FBT 
from model_fct import*
from Sudakov.sudakov_factor import*
from Sudakov.evolve import evolve, sng

# %%
scl =Soft(0)

# %%
scl.bmax
# Out:
# 0.8

# %%
bts = linspace(0.001,6,1000)

# %%
zh = 0.6
plt.figure(figsize=(8, 8))
plt.plot(bts,scl.g_K_1h(bts),linestyle='--',label = 'log_b',linewidth=3)
plt.plot(bts,scl.g_K_ll_1h_lgm(bts,zh),label = 'll_lgm',linewidth=3)
#plt.plot(bts,scl.g_K_1h_lgm(bts,zh),label = 'log_b_lgm'm,linewidth=3)
#plt.plot(bts,scl.g_K_ll_1h_lgm_n(bts,zh),label = 'll_lgm_new',linewidth=3)
plt.plot(bts,scl.g_K_exp_1h_lgm(bts,zh),label = 'exp',linewidth=3)
plt.xlabel('$b_T$',size=20)
plt.ylabel('$g_K(b_T)$',size=20)
plt.ylim(0.,1.1)
plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.legend(loc=1, prop={'size': 20})

# %%
zh1 = 0.6
zh2=0.45
had2='k+'
bts = linspace(0.01,2.,500)
plot(bts,scl.g_K(bts),label = 'log_b')
plot(bts,scl.g_K_ll_lgm(bts,had2,zh1,zh2),label = 'll_lgm')
#plot(bts,scl.g_K_lgm(bts,had2,zh1,zh2),label = 'log_b_lgm')
#plot(bts,scl.g_K_ll_lgm_n(bts,had2,zh1,zh2),label = 'll_lgm_new')
plot(bts,scl.g_K_exp_lgm(bts,had2,zh1,zh2),label = 'exp')
legend()

# %%
zh = 0.35
bts = linspace(0.001,4.5,1000)
plt.figure(figsize=(11, 8))
plt.plot(bts,scl.g_K_1h(bts),linestyle='--',label = '$\log(b_T/b_*)$  (1)',linewidth=3)
plt.plot(bts,scl.g_K_ll_1h_lgm(bts,zh),linestyle='dashdot',label = '$\log(1+ b^2_T/b^2_{max})$ (2)',linewidth=3)
#plt.plot(bts,scl.g_K_1h_lgm(bts,zh),label = 'log_b_lgm'm,linewidth=3)
#plt.plot(bts,scl.g_K_ll_1h_lgm_n(bts,zh),label = 'll_lgm_new',linewidth=3)
plt.plot(bts,scl.g_K_exp_1h_lgm(bts,zh),label = 'exp (3)',linewidth=3)
plt.plot(bts,scl.g_K_new_1h_lgm(bts,zh),linestyle='dotted',label = 'gauss (4)',linewidth=3)

#
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$g_K(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})
# Out:
# /home/zackmrc/Documenti/git_project/lambda_fit/def_convolution_v3.1_survey/Sudakov/sudakov_factor.py:543: RuntimeWarning: divide by zero encountered in double_scalars
#   term = term/ml1

# %%
pwd
# Out:
# '/home/zackmrc/Documenti/git_project/lambda_fit/def_convolution_v3.1_survey'

# %%
zh = 0.25
zh1 = 0.25
zh2=0.45
had2='pi+'
bts = linspace(0.001,4.5,1000)
plt.figure(figsize=(11, 8))
plt.plot(bts,scl.g_K(bts),linestyle='--',label = '$\log(b_T/b_*)$  (1)',linewidth=3)
plt.plot(bts,scl.g_K_ll_lgm(bts,had2,zh1,zh2),linestyle='dashdot',label = '$\log(1+ b^2_T/b^2_{max})$ (2)',linewidth=3)
plt.plot(bts,scl.g_K_exp_lgm(bts,had2,zh1,zh2),label = 'exp (3)',linewidth=3)
plt.plot(bts,scl.g_K_new_lgm(bts,had2,zh1,zh2),linestyle='dotted',label = 'gauss (4)',linewidth=3)
plt.plot(bts,scl.g_K_bac_lgm(bts,had2,zh1,zh2),linestyle=(0, (3, 1, 1, 1, 1, 1)),label='PV17 (5)',linewidth=3)
#
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$g_K(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})

# %%
mdl = model_bt()
zh=0.35
plt.figure(figsize=(10, 8))

#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law $p=2$')
plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=3, prop={'size': 20})

# %%
mdl = model_bt()
zh=0.35
plt.figure(figsize=(14, 8))

plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law $p=2$')
plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=3, prop={'size': 20})
# Out:
# /home/zackmrc/Documenti/git_project/lambda_fit/def_convolution_v3.1_survey/model_fct.py:65: RuntimeWarning: floating point number truncated to an integer
#   bssl = special.kn(pwr-1,b_new*mass)

# %%
eta=0.2
bts = linspace(0.01,6,500)
plot(bts,e**(-bts/eta/10.58),label='1')
plot(bts,e**(-(bts/eta/10.58)**2),label='2')
legend()

# %%
eta*10
# Out:
# 2.0

# %%
mdl = model_bt()
zh=0.45
plt.figure(figsize=(14, 8))

#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law (1) $p=2$, $m=1$' )
plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
plt.plot(bts,mdl.MD_bstar(bts,2,zh,1.),linestyle='dotted',linewidth=3,label='Power Law (2) $p=2$, $m=1$' )
plt.plot(bts,mdl.MD_pv17(bts,zh),linestyle=(0, (3, 1, 1, 1, 1, 1)),linewidth=3,label='PV17')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})

# %%
mdl = model_bt()
zh=0.45
plt.figure(figsize=(14, 8))

#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD(bts,2,1.),linestyle='dashdot',linewidth=3,label='Power Law (1) $p=2$, $m=1$' )
plt.plot(bts,mdl.MD(bts,2.,.5),linestyle='dashdot',linewidth=3,label='Power Law (1) $p=2$, $m=0.05$' )

#plt.plot(bts,mdl.MD_gauss(bts,zh,0.2),linewidth=3,label='Gaussian $wdt=0.2$')
plt.plot(bts,mdl.MD_bstar(bts,2,zh,1.),linestyle='dotted',linewidth=3,label='Power Law (2) $p=2$, $m=1$' )
plt.plot(bts,mdl.MD_bstar(bts,3.5,zh,.5),linestyle='dotted',linewidth=3,label='Power Law (2) $p=3.5$, $m=0.5$' )

#plt.plot(bts,mdl.MD_pv17(bts,zh),linestyle=(0, (3, 1, 1, 1, 1, 1)),linewidth=3,label='PV17')
#plt.plot(bts,mdl.MD_gauss(bts,zh,0.007),linestyle='dotted',linewidth=3,label='Gaussian $wdt=0.007$')
##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})
# Out:
# /home/zackmrc/Documenti/git_project/lambda_fit/def_convolution_v3.1_survey/model_fct.py:142: RuntimeWarning: floating point number truncated to an integer
#   bssl1 = special.kn(pwr-1,b_new*mass)

# %%
eta = [.1,.15,.2,.22,.25,.27,.3]
gauss_star = [1.561,1.115,1.172,1.169,1.191,1.219,1.265]
star_star = [1.682,2.76,1.204,1.187,1.202,1.229,1.271]
star_pwrlw = [5.3,2.217,1.354,1.462,1.22,1.346,1.29]

# %%
plt.figure(figsize=(13, 8))
plot(eta,gauss_star,'--o',label='gauss on pwrlw_z')
plot(eta,star_star,'--o',label='pwrlw_z on pwrlw_z')
plot(eta,star_pwrlw,'--o',label='pwrlw_z on pwrlw')
plt.xlabel('$q_{T_{max}}/Q$',size=30)
plt.ylabel('$\chi^2_{dof}$',size=30)
#plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})

# %%
pwd
# Out:
# '/home/zackmrc/Documenti/git_project/lambda_fit/def_convolution_v3.1_survey'

# %%
┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
│   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
│ 0 │ NUP  │   0.196   │   0.029   │   -0.029   │   0.029    │         │         │       │
│ 1 │ NDO  │  -0.2194  │  0.0026   │  -0.0026   │   0.0026   │         │         │       │
│ 2 │ NST  │  -0.340   │   0.005   │   -0.005   │   0.005    │         │         │       │
│ 3 │ NSEA │ -111.7e-3 │  0.8e-3   │  -0.8e-3   │   0.8e-3   │         │         │       │
│ 4 │ AUP  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 5 │ ADO  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 6 │ AST  │   2.458   │   0.021   │   -0.021   │   0.021    │    0    │         │       │
│ 7 │ ASEA │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 8 │ BUP  │   3.338   │   0.028   │   -0.028   │   0.028    │    0    │         │       │
│ 9 │ BDO  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 10│ BST  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 11│ BSEA │    2.1    │    0.6    │    -0.6    │    0.6     │    0    │         │       │
│ 12│ PP   │   2.69    │   0.01    │   -0.01    │    0.01    │    1    │         │       │
│ 13│ MSS  │  0.3986   │  0.0029   │  -0.0029   │   0.0029   │    0    │         │       │
└───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# Out:
#   File "<ipython-input-19-91a1f2b7816b>", line 1
#     ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
#                                                                                              ^
# SyntaxError: invalid character in identifier

# %%
┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
│   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
│ 0 │ NUP  │  0.198    │ 0.011e-3  │            │            │         │         │       │
│ 1 │ NDO  │ -0.2395   │0.000025e-3│            │            │         │         │       │
│ 2 │ NST  │ -0.287    │ 0.004e-3  │            │            │         │         │       │
│ 3 │ NSEA │ -0.113    │ 0.009e-3  │            │            │         │         │       │
│ 4 │ AUP  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 5 │ ADO  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 6 │ AST  │  2.256    │ 0.000018  │            │            │    0    │         │       │
│ 7 │ ASEA │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 8 │ BUP  │  3.1638   │ 0.000024  │            │            │    0    │         │       │
│ 9 │ BDO  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 10│ BST  │   0.00    │   0.01    │            │            │    0    │         │  yes  │
│ 11│ BSEA │  2.0446   │  0.0005   │            │            │    0    │         │       │
│ 12│ PP2  │  2.699    │ 0.000009  │            │            │    1    │         │       │
│ 13│ MSS2 │  0.412    │ 0.0026e-3 │            │            │    0    │         │       │
│ 14│ PP1  │  1.649    │ 0.000010  │            │            │    1    │         │       │
│ 15│ MSS1 │  0.576    │0.00011e-3 │            │            │    0    │         │       │
└───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
mdl = model_bt()
x_lbl=30
zh=0.25
bts = linspace(0.0001,6,500)
plt.figure(figsize=(10, 8))
pp2=2.69
mss2=0.412

pp1=1.65
mss1=0.576
#plt.plot(bts,mdl.MD(bts,2.3,1.),linestyle='--',linewidth=3,label='Power Law $p=2.3$')
plt.plot(bts,mdl.MD_bstar(bts,pp2,zh,mss2),linestyle='dashdot',linewidth=3,label='Power Law (2) $p='+str(pp2)+ '$, $m='+str(mss2)+ '$' )
plt.plot(bts,mdl.MD_bstar(bts,pp1,zh,mss1),linestyle='dotted',linewidth=3,label='Power Law (2) $p='+str(pp1)+ '$, $m='+str(mss1)+ '$' )

##
#
plt.xlabel('$b_T$',size=30)
plt.ylabel('$M_D(b_T)$',size=30)
plt.xlim(-0.1,3)
plt.ylim(-0.1,1.1)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(loc=1, prop={'size': 20})
plt.text(2., 0.7, r'$z_{h} = '+str(zh)+'$', ha='center',size=x_lbl)
# Out:
# Text(2.0, 0.7, '$z_{h} = 0.25$')
