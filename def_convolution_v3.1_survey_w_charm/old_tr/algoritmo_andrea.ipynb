# %%
# -*- coding: utf-8 -*-
from pylab import*
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*
import pandas as pd

# %%
data = pd.read_csv("exp_data/lambda_jet_global.dat", delimiter=r"\s+", header=0, engine='python')

# %%
coef=0.2

tau=0.1

# %%
data
# Out:
#      h1  jet    z1    pt   P_exp   P(theo)       err     unpol
# 0   300  999  0.25  0.13  0.0198 -0.007436  0.007212  0.155700
# 1   300  999  0.25  0.34 -0.0078 -0.014850  0.002837  0.095040
# 2   300  999  0.26  0.60 -0.0033 -0.012880  0.003579  0.025860
# 3   300  999  0.28  0.88 -0.0134 -0.006057  0.009888  0.002765
# 4   300  999  0.34  0.13 -0.0301 -0.011510  0.014370  0.072870
# 5   300  999  0.35  0.34 -0.0251 -0.025610  0.003803  0.040780
# 6   300  999  0.35  0.62  0.0004 -0.022420  0.004569  0.010640
# 7   300  999  0.35  0.96 -0.0117 -0.008008  0.006981  0.000725
# 8   300  999  0.44  0.13 -0.0683 -0.027700  0.028430  0.031680
# 9   300  999  0.44  0.35 -0.0534 -0.055900  0.007215  0.018680
# 10  300  999  0.45  0.63 -0.0431 -0.050340  0.008165  0.004378
# 11  300  999  0.45  0.99 -0.0228 -0.016090  0.010300  0.000237
# 12  300  999  0.59  0.13 -0.0398 -0.046710  0.047650  0.008537
# 13  300  999  0.59  0.35 -0.0466 -0.094260  0.014770  0.005035
# 14  300  999  0.59  0.63 -0.0876 -0.080210  0.013360  0.001277
# 15  300  999  0.60  1.04 -0.0670 -0.020910  0.014870  0.000037
# 16  310  999  0.25  0.13 -0.0009 -0.007436  0.007561  0.155700
# 17  310  999  0.25  0.34 -0.0069 -0.014850  0.003082  0.095040
# 18  310  999  0.26  0.60 -0.0034 -0.012880  0.004083  0.025860
# 19  310  999  0.28  0.88 -0.0002 -0.006057  0.011030  0.002765
# 20  310  999  0.34  0.13 -0.0229 -0.011510  0.015460  0.072870
# 21  310  999  0.35  0.34 -0.0229 -0.025610  0.004102  0.040780
# 22  310  999  0.35  0.62 -0.0014 -0.022420  0.004924  0.010640
# 23  310  999  0.35  0.96  0.0038 -0.008008  0.007380  0.000725
# 24  310  999  0.44  0.13 -0.0308 -0.027700  0.030820  0.031680
# 25  310  999  0.44  0.35 -0.0637 -0.055900  0.007688  0.018680
# 26  310  999  0.45  0.63 -0.0303 -0.050340  0.008621  0.004378
# 27  310  999  0.45  0.99 -0.0151 -0.016090  0.010390  0.000237
# 28  310  999  0.59  0.13  0.0912 -0.046710  0.057690  0.008537
# 29  310  999  0.59  0.35 -0.0743 -0.094260  0.013400  0.005035
# 30  310  999  0.59  0.63 -0.0743 -0.080210  0.013330  0.001277
# 31  310  999  0.60  1.04 -0.0741 -0.020910  0.015680  0.000037

# %%
Q=10.58
mh=1.115
data['yp']=np.log( data['z1']*Q/np.sqrt(data['pt']**2 + mh**2) )

# %%
data['rs']=(data['pt']/data['z1']/Q)*np.exp(-data['yp'])

# %%
data['rc'] = data['z1']*(1-data['z1'])*np.exp(-2*data['yp'])

# %%
data['qt_Q']=(data['pt']/data['z1']/Q)

# %%
data['exp']=np.exp(-data['yp'])

# %%
data
# Out:
# 8   0.006734  0.014328  0.027926  0.241140
# 9   0.018874  0.015528  0.075185  0.251040
# 10  0.035594  0.017908  0.132325  0.268993
# 11  0.065124  0.024276  0.207940  0.313187
# 12  0.003745  0.007823  0.020826  0.179833
# 13  0.010497  0.008479  0.056070  0.187216
# 14  0.020706  0.010182  0.100926  0.205164
# 15  0.039351  0.013846  0.163831  0.240192
# 16  0.020859  0.033773  0.049149  0.424406
# 17  0.056651  0.036418  0.128544  0.440713
# 18  0.100399  0.040764  0.218118  0.460297
# 19  0.142435  0.046349  0.297056  0.479487
# 20  0.011278  0.021853  0.036139  0.312063
# 21  0.028904  0.022544  0.091817  0.314795
# 22  0.057685  0.027004  0.167432  0.344527
# 23  0.103009  0.035917  0.259249  0.397336
# 24  0.006734  0.014328  0.027926  0.241140
# 25  0.018874  0.015528  0.075185  0.251040
# 26  0.035594  0.017908  0.132325  0.268993
# 27  0.065124  0.024276  0.207940  0.313187
# 28  0.003745  0.007823  0.020826  0.179833
# 29  0.010497  0.008479  0.056070  0.187216
# 30  0.020706  0.010182  0.100926  0.205164
# 31  0.039351  0.013846  0.163831  0.240192

# %%
dr_pr2=data.loc[(data['rs']>coef*tau)]
dr_pr1=data.loc[(data['rs']<coef*tau)]

# %%
df_R1=dr_pr1.loc[(data['qt_Q'] <coef*data['exp'])]

# %%
df_R1
# Out:
#      h1  jet    z1    pt   P_exp  P(theo)      err     unpol        yp  \
# 4   300  999  0.34  0.13 -0.0301 -0.01151  0.01437  0.072870  1.164550
# 8   300  999  0.44  0.13 -0.0683 -0.02770  0.02843  0.031680  1.422379
# 12  300  999  0.59  0.13 -0.0398 -0.04671  0.04765  0.008537  1.715727
# 20  310  999  0.34  0.13 -0.0229 -0.01151  0.01546  0.072870  1.164550
# 24  310  999  0.44  0.13 -0.0308 -0.02770  0.03082  0.031680  1.422379
# 28  310  999  0.59  0.13  0.0912 -0.04671  0.05769  0.008537  1.715727
#
#           rs        rc      qt_Q       exp
# 4   0.011278  0.021853  0.036139  0.312063
# 8   0.006734  0.014328  0.027926  0.241140
# 12  0.003745  0.007823  0.020826  0.179833
# 20  0.011278  0.021853  0.036139  0.312063
# 24  0.006734  0.014328  0.027926  0.241140
# 28  0.003745  0.007823  0.020826  0.179833

# %%
df_R2=dr_pr1.loc[(data['qt_Q'] >coef*data['exp'])]
df_R2
# Out:
#      h1  jet    z1    pt   P_exp  P(theo)       err     unpol        yp  \
# 9   300  999  0.44  0.35 -0.0534 -0.05590  0.007215  0.018680  1.382142
# 13  300  999  0.59  0.35 -0.0466 -0.09426  0.014770  0.005035  1.675490
# 25  310  999  0.44  0.35 -0.0637 -0.05590  0.007688  0.018680  1.382142
# 29  310  999  0.59  0.35 -0.0743 -0.09426  0.013400  0.005035  1.675490
#
#           rs        rc      qt_Q       exp
# 9   0.018874  0.015528  0.075185  0.251040
# 13  0.010497  0.008479  0.056070  0.187216
# 25  0.018874  0.015528  0.075185  0.251040
# 29  0.010497  0.008479  0.056070  0.187216

# %%
df_R22 = dr_pr2.loc[(dr_pr2['rc']<coef*tau)]
df_R22
# Out:
#      h1  jet    z1    pt   P_exp  P(theo)       err     unpol        yp  \
# 10  300  999  0.45  0.63 -0.0431 -0.05034  0.008165  0.004378  1.313072
# 14  300  999  0.59  0.63 -0.0876 -0.08021  0.013360  0.001277  1.583946
# 15  300  999  0.60  1.04 -0.0670 -0.02091  0.014870  0.000037  1.426317
# 26  310  999  0.45  0.63 -0.0303 -0.05034  0.008621  0.004378  1.313072
# 30  310  999  0.59  0.63 -0.0743 -0.08021  0.013330  0.001277  1.583946
# 31  310  999  0.60  1.04 -0.0741 -0.02091  0.015680  0.000037  1.426317
#
#           rs        rc      qt_Q       exp
# 10  0.035594  0.017908  0.132325  0.268993
# 14  0.020706  0.010182  0.100926  0.205164
# 15  0.039351  0.013846  0.163831  0.240192
# 26  0.035594  0.017908  0.132325  0.268993
# 30  0.020706  0.010182  0.100926  0.205164
# 31  0.039351  0.013846  0.163831  0.240192

# %%
df_R3 = dr_pr2.loc[(dr_pr2['rc']>coef*tau)]
df_R3
# Out:
#      h1  jet    z1    pt   P_exp   P(theo)       err     unpol        yp  \
# 0   300  999  0.25  0.13  0.0198 -0.007436  0.007212  0.155700  0.857066
# 1   300  999  0.25  0.34 -0.0078 -0.014850  0.002837  0.095040  0.819361
# 2   300  999  0.26  0.60 -0.0033 -0.012880  0.003579  0.025860  0.775883
# 3   300  999  0.28  0.88 -0.0134 -0.006057  0.009888  0.002765  0.735039
# 5   300  999  0.35  0.34 -0.0251 -0.025610  0.003803  0.040780  1.155833
# 6   300  999  0.35  0.62  0.0004 -0.022420  0.004569  0.010640  1.065582
# 7   300  999  0.35  0.96 -0.0117 -0.008008  0.006981  0.000725  0.922974
# 11  300  999  0.45  0.99 -0.0228 -0.016090  0.010300  0.000237  1.160956
# 16  310  999  0.25  0.13 -0.0009 -0.007436  0.007561  0.155700  0.857066
# 17  310  999  0.25  0.34 -0.0069 -0.014850  0.003082  0.095040  0.819361
# 18  310  999  0.26  0.60 -0.0034 -0.012880  0.004083  0.025860  0.775883
# 19  310  999  0.28  0.88 -0.0002 -0.006057  0.011030  0.002765  0.735039
# 21  310  999  0.35  0.34 -0.0229 -0.025610  0.004102  0.040780  1.155833
# 22  310  999  0.35  0.62 -0.0014 -0.022420  0.004924  0.010640  1.065582
# 23  310  999  0.35  0.96  0.0038 -0.008008  0.007380  0.000725  0.922974
# 27  310  999  0.45  0.99 -0.0151 -0.016090  0.010390  0.000237  1.160956
#
#           rs        rc      qt_Q       exp
# 0   0.020859  0.033773  0.049149  0.424406
# 1   0.056651  0.036418  0.128544  0.440713
# 2   0.100399  0.040764  0.218118  0.460297
# 3   0.142435  0.046349  0.297056  0.479487
# 5   0.028904  0.022544  0.091817  0.314795
# 6   0.057685  0.027004  0.167432  0.344527
# 7   0.103009  0.035917  0.259249  0.397336
# 11  0.065124  0.024276  0.207940  0.313187
# 16  0.020859  0.033773  0.049149  0.424406
# 17  0.056651  0.036418  0.128544  0.440713
# 18  0.100399  0.040764  0.218118  0.460297
# 19  0.142435  0.046349  0.297056  0.479487
# 21  0.028904  0.022544  0.091817  0.314795
# 22  0.057685  0.027004  0.167432  0.344527
# 23  0.103009  0.035917  0.259249  0.397336
# 27  0.065124  0.024276  0.207940  0.313187

# %%
df_RR2=df_R2

# %%
df_RR2=df_RR2.append(df_R22)

# %% [markdown]
# Plotter: con diversi colori in base alla regione

# %%
fig4, axes = plt.subplots(1,4)
lim=[-0.15,0.15]
z1=[0.25,.35,.45,.6]
ct=1
cl_r='orange'
cl_b='red'
cl_g='green'

ers_bar = 1.2  # dimensione barre errore
pnt_dat = 6 # dimensione punti

title_s=35 #dimensione titolo bin

fit_l=3.  # dimensione linea fit
y_lbl=48
x_lbl =50

# %%
fig4, axes = plt.subplots(1,4)
lim=[-0.15,0.15]
z1=[0.25,.35,.45,.6]
ct=1
cl_r='orange'
cl_b='red'
cl_g='green'

ers_bar = 1.2  # dimensione barre errore
pnt_dat = 6 # dimensione punti

title_s=35 #dimensione titolo bin

fit_l=3.  # dimensione linea fit
y_lbl=48
x_lbl =50
for zs, ax in zip(z1,axes):

    lim=[-0.15,0.15]

    fig4.suptitle('$\Lambda$ - thrust coef ')
    pnt1 = df_RR2.loc[(df_RR2['h1']==300) & (df_RR2['z1']< zs+0.05) & (df_RR2['z1']> zs-0.05)]  
    pnt2 = df_RR2.loc[(df_RR2['h1']==310) & (df_RR2['z1']< zs+0.05) & (df_RR2['z1']> zs-0.05)] 
#
    pnt11 = df_R3.loc[(df_R3['h1']==300) & (df_R3['z1']< zs+0.05) & (df_R3['z1']> zs-0.05)]  
    pnt22 = df_R3.loc[(df_R3['h1']==310) & (df_R3['z1']< zs+0.05) & (df_R3['z1']> zs-0.05)] 
#    
    pnt111 = df_R1.loc[(df_R1['h1']==300) & (df_R1['z1']< zs+0.05) & (df_R1['z1']> zs-0.05)]  
    pnt222 = df_R1.loc[(df_R1['h1']==310) & (df_R1['z1']< zs+0.05) & (df_R1['z1']> zs-0.05)] 
    
#    pnt1.astype(float)
#    pnt2.astype(float)
    ax=plt.subplot(1,4,ct)
    ax.scatter(pnt1.pt, pnt1.P_exp, s=50 ,  color=cl_r,label= 'region2')
    ax.scatter(pnt2.pt, pnt2.P_exp,    color=cl_r, label= 'region2')
    ax.scatter(pnt11.pt, pnt11.P_exp,    color=cl_g,label= 'region3')
    ax.scatter(pnt22.pt, pnt22.P_exp,    color=cl_g, label= 'region3')
    ax.scatter(pnt111.pt, pnt111.P_exp,    color=cl_b,label= 'region1')
    ax.scatter(pnt222.pt, pnt222.P_exp,    color=cl_b, label= 'region1')

    tick_params(axis='both', which='major', labelsize=25)

#    if zs==0.25 :	title("0.2<$z_{\Lambda}$<0.3  ",fontsize=title_s,x=0.5, y=1.)
#    elif zs==0.35 :	title("0.3<$z_{\Lambda}$<0.4",fontsize=title_s,x=0.5, y=1.)
#    elif zs==0.45 :	title("0.4<$z_{\Lambda}$<0.5",fontsize=title_s,x=0.5, y=1.)
#    elif zs==0.6 :	title("0.5<$z_{\Lambda}$<0.9",fontsize=title_s,x=0.5, y=1.)

    if ct==1 : ylabel('Polarization',size=y_lbl)
    if ct !=1 :ax.set_yticklabels([])
    axhline(linewidth=1.5, ls=':', color='g')

    ax.set_ylim(lim)
    ct+=1
    
fig4.subplots_adjust(top=0.8,bottom=0.2,left=0.1,right=0.99,hspace=0.2,wspace=0.0)

fig4.set_size_inches(19.5, 10.5, forward=True)
#
