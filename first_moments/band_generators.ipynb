# %%
from first_moments import*
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*

# %%
mean2h= array([ 0.09341723, -0.1000179,  -0.11673005, -0.05501322,-0.05501322,-0.05501322,  0.,          0.,
  2.19397263,  0.,0.,0., 3.47205659 , 0., 0. , 2.31910624,2.31910624,2.31910624])

# %%
mean2h=array([ 0.09965859, -0.10666305, -0.1150868 , -0.05767081, -0.05767081, -0.05767081,  0.        ,
         0.        ,  2.11951497,  0.,  0.,  0.        ,  3.50037005,  0.        ,
         0.        ,  2.27198031,  2.27198031,  2.27198031])

# %%
fst = cr_sec()
zs = linspace(0.25,0.95,100)
qq=10.58
fst.mass=1.115

# %%
fst_moms = array([])
for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

# %%
fst_moms1 = array([])
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms2 = array([])
for z1 in zs:
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms3 = array([])
for z1 in zs:
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms4 = array([])
for z1 in zs:
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms5 = array([])
for z1 in zs:
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
pwd
# Out:
# '/home/zackmrc/Documenti/git_project/SIDIS_epem_git/first_moments'

# %%
plot(zlcs,fst_moms)
plot(zlcs,fst_moms1)
plot(zlcs,fst_moms2)
plot(zlcs,fst_moms3)

# %%
df1 = pd.read_csv('fit_parameters/new_bands_/new_gauss_211.csv')
df2 = pd.read_csv('fit_parameters/new_bands_/new_gauss_345.csv')
df3 = pd.read_csv('fit_parameters/new_bands_/new_gauss_3673.csv')
df_gauss = pd.concat([df1,df2,df3])
chi_min = 104.9
df_gauss = df_gauss.loc[(df_gauss['chi']<chi_min+15.79)]

# %%
up_min= array([])
do_min = array([])
st_min = array([])

upb_min = array([])
dob_min = array([])
stb_min = array([])

up_max= array([])
do_max = array([])
st_max = array([])

upb_max = array([])
dob_max = array([])
stb_max = array([])


for z1 in zs:
    up_tmp = array([])
    do_tmp = array([])
    st_tmp = array([])

    upb_tmp = array([])
    dob_tmp = array([])
    stb_tmp = array([])
    for nup, ndo, nst, nsea, ast, bup, bsea in zip(df_gauss.NUP,df_gauss.NDO,df_gauss.NST,df_gauss.NSEA,df_gauss.AST,df_gauss.BUP,df_gauss.BSEA):

        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = ndo#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = f_prm[3] #par[0]      #dob
        f_prm[5] = f_prm[3] # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = 0 #par[0]      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = f_prm[9] #par[0]      #adob
        f_prm[11] = f_prm[9] #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = 0 #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = bsea #par[0]      #bupb
        f_prm[16] = f_prm[15] #par[0]      #bdob
        f_prm[17] = f_prm[15] # par[0]      #bstb
        #print(pt_pp)
        #print(nup)
        #print(fst.cross_sec2_polda('lbd',z1,qq,f_prm)[0])
        up_tmp = np.append(up_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[0])
        do_tmp = np.append(do_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[1])
        st_tmp = np.append(st_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[2])

        upb_tmp = np.append(upb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[3])
        dob_tmp = np.append(dob_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[4])
        stb_tmp = np.append(stb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[5])
        
    up_min= np.append(up_min,min(up_tmp))
    do_min = np.append(do_min,min(do_tmp))
    st_min = np.append(st_min,min(st_tmp))

    upb_min = np.append(upb_min,min(upb_tmp))
    dob_min = np.append(dob_min,min(dob_tmp))
    stb_min = np.append(stb_min,min(stb_tmp))

    up_max= np.append(up_max,max(up_tmp))
    do_max = np.append(do_max,max(do_tmp))
    st_max = np.append(st_max,max(st_tmp))

    upb_max = np.append(upb_max,max(upb_tmp))
    dob_max = np.append(dob_max,max(dob_tmp))
    stb_max = np.append(stb_max,max(stb_tmp))

# %%
a =pd.DataFrame([])

a['UP'] = fst_moms
a['DO'] = fst_moms1
a['ST'] = fst_moms2
a['UPb'] = fst_moms3
a['DOb'] = fst_moms4
a['STb'] = fst_moms5
a['UP_min'] = up_min
a['DO_min'] = do_min
a['ST_min'] = st_min
a['UPb_min'] = upb_min
a['DOb_min'] = dob_min
a['STb_min'] = stb_min

a['UP_max'] = up_max
a['DO_max'] = do_max
a['ST_max'] = st_max
a['UPb_max'] = upb_max
a['DOb_max'] = dob_max
a['STb_max'] = stb_max

a['zs']=zlcs

# %%
a
# Out:
#               UP            DO            ST           UPb           DOb  \
# 0   4.031736e-03 -7.390767e-03 -1.565315e-04 -2.697297e-03 -2.509036e-03
# 1   3.479784e-03 -6.486308e-03 -1.550309e-04 -2.328445e-03 -2.116857e-03
# 2   3.066919e-03 -5.798488e-03 -1.549057e-04 -2.052726e-03 -1.819553e-03
# 3   2.747756e-03 -5.263315e-03 -1.558900e-04 -1.839744e-03 -1.588284e-03
# 97 -1.533640e-14 -1.621133e-14 -2.104443e-12  0.923836
# 98 -6.019545e-15 -6.323335e-15 -8.251679e-13  0.931000
# 99 -2.190131e-15 -2.271255e-15 -2.982366e-13  0.938161
#
# [100 rows x 19 columns]

# %%
a.to_csv('first_moments_2h_new.csv')

# %% [markdown]
# # Power law doppio modello

# %%
df1 = pd.read_csv('fit_parameters/new_bands_/new_pwrlw_211.csv')
df2 = pd.read_csv('fit_parameters/new_bands_/new_pwrlw_345.csv')
df3 = pd.read_csv('fit_parameters/new_bands_/new_pwrlw_3673.csv')
df_gauss = pd.concat([df1,df2,df3])
chi_min = 181.5
df_gauss = df_gauss.loc[(df_gauss['chi']<chi_min+19.99)]

# %%
mean2h= array([ 0.1481, -0.165,  -0.137, -0.0810,  -0.0810,-0.0810,  0.,          0.,
  1.85,  0.,0.,0., 3.438 , 0., 0. , 2.103,2.103,2.103])

# %%
fst_moms = array([])
for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
fst_moms1 = array([])
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms2 = array([])
for z1 in zs:
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms3 = array([])
for z1 in zs:
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms4 = array([])
for z1 in zs:
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms5 = array([])
for z1 in zs:
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

# %%
plot(zs,fst_moms)
plot(zs,fst_moms1)
plot(zs,fst_moms2)
plot(zs,fst_moms3)

# %%
up_min= array([])
do_min = array([])
st_min = array([])

upb_min = array([])
dob_min = array([])
stb_min = array([])

up_max= array([])
do_max = array([])
st_max = array([])

upb_max = array([])
dob_max = array([])
stb_max = array([])


for z1 in zs:
    up_tmp = array([])
    do_tmp = array([])
    st_tmp = array([])

    upb_tmp = array([])
    dob_tmp = array([])
    stb_tmp = array([])
    for nup, ndo, nst, nsea, ast, bup, bsea in zip(df_gauss.NUP,df_gauss.NDO,df_gauss.NST,df_gauss.NSEA,df_gauss.AST,df_gauss.BUP,df_gauss.BSEA):

        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = ndo#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = f_prm[3] #par[0]      #dob
        f_prm[5] = f_prm[3] # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = 0 #par[0]      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = f_prm[9] #par[0]      #adob
        f_prm[11] = f_prm[9] #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = 0 #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = bsea #par[0]      #bupb
        f_prm[16] = f_prm[15] #par[0]      #bdob
        f_prm[17] = f_prm[15] # par[0]      #bstb
        #print(pt_pp)
        #print(nup)
        #print(fst.cross_sec2_polda('lbd',z1,qq,f_prm)[0])
        up_tmp = np.append(up_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[0])
        do_tmp = np.append(do_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[1])
        st_tmp = np.append(st_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[2])

        upb_tmp = np.append(upb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[3])
        dob_tmp = np.append(dob_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[4])
        stb_tmp = np.append(stb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[5])
        
    up_min= np.append(up_min,min(up_tmp))
    do_min = np.append(do_min,min(do_tmp))
    st_min = np.append(st_min,min(st_tmp))

    upb_min = np.append(upb_min,min(upb_tmp))
    dob_min = np.append(dob_min,min(dob_tmp))
    stb_min = np.append(stb_min,min(stb_tmp))

    up_max= np.append(up_max,max(up_tmp))
    do_max = np.append(do_max,max(do_tmp))
    st_max = np.append(st_max,max(st_tmp))

    upb_max = np.append(upb_max,max(upb_tmp))
    dob_max = np.append(dob_max,max(dob_tmp))
    stb_max = np.append(stb_max,max(stb_tmp))

# %%
b =pd.DataFrame([])

b['UP'] = fst_moms
b['DO'] = fst_moms1
b['ST'] = fst_moms2
b['UPb'] = fst_moms3
b['DOb'] = fst_moms4
b['STb'] = fst_moms5
b['UP_min'] = up_min
b['DO_min'] = do_min
b['ST_min'] = st_min
b['UPb_min'] = upb_min
b['DOb_min'] = dob_min
b['STb_min'] = stb_min

b['UP_max'] = up_max
b['DO_max'] = do_max
b['ST_max'] = st_max
b['UPb_max'] = upb_max
b['DOb_max'] = dob_max
b['STb_max'] = stb_max

b['zs']=zlcs

# %%
b
# Out:
#               UP            DO            ST           UPb           DOb  \
# 0   6.430121e-03 -1.219258e-02 -3.442175e-04 -4.125140e-03 -3.837222e-03
# 1   5.551982e-03 -1.070049e-02 -3.342564e-04 -3.569823e-03 -3.245428e-03
# 2   4.895155e-03 -9.565793e-03 -3.278936e-04 -3.154856e-03 -2.796491e-03
# 3   4.387432e-03 -8.682915e-03 -3.243316e-04 -2.834474e-03 -2.447051e-03
# 4   3.981622e-03 -7.982862e-03 -3.231000e-04 -2.578721e-03 -2.169038e-03
# ..           ...           ...           ...           ...           ...
# 95  9.249239e-10 -5.448763e-08 -4.798569e-06 -1.340954e-09 -2.804353e-11
# 96  1.342868e-11 -3.694621e-08 -3.287528e-06 -2.021292e-11 -1.533436e-11
