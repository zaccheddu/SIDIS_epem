# %%
from first_moments import*
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*

# %%
fst = cr_sec()
zs = linspace(0.25,0.95,100)
qq=10.58
fst.mass=1.115

# %%
mean1=array( [0.093, -0.100,  -0.117, -0.055,-0.055,-0.055,  0., 0., 2.19,  0.,0.,0.,  3.5,  0., 0., 2.3,2.3,2.3])
mean2=array([ 0.1135492,  -0.11525894, -0.08833732, -0.06032414,-0.06032414,-0.06032414,  0., 0., 0.8659928, 0., 0., 0., 2.59542954, 0.,  0., 0.67835136, 0.67835136,  0.67835136  ])
mean3=array([ 0.08830226, -0.1184549,  -0.06675146, -0.04596938,-0.04596938,-0.04596938,  0.,0.,  0.34150793,  0.,0.,0.,2.2378779, 0.,0.,0.62686554,0.62686554,0.62686554])
mean4=array([ 0.13730469,0.13730469,  -0.13225338, -0.11692807,-0.11692807,-0.07811196,\
              0.,0.,  1.61875805,  0.,0.,0.,\
             2.28736638, 2.28736638, 0.03103877,0.,0., 1.19867128])
mean2h= array([ 0.09341723, -0.1000179,  -0.11673005, -0.05501322,-0.05501322,-0.05501322,  0.,          0.,
  2.19397263,  0.,0.,0., 3.47205659 , 0., 0. , 2.31910624,2.31910624,2.31910624])

# %%
fst_moms1 = array([])

# %%
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[0])
    #print(fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[0])

# %%
#fst.cross_sec2_polda_jk('lbd',zs,qq,mean1)[0]
#fst.cross_sec2_polda_jk('lbd',zs,qq,mean2)[0]

# %%
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean1)[0])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean2)[0])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean3)[0])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean4)[0])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean2h)[0])

# %%
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean1)[1])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean2)[1])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean3)[1])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean4)[1])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean2h)[1])

# %%
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean1)[2])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean2)[2])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean3)[2])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean4)[2])
plot(zs,fst.cross_sec2_polda_jk('lbd',zs,qq,mean2h)[2])
