# %%
import pandas as pd
from numpy import*

# %%
gauss1=pd.read_csv('lk_point_gauss_1.csv',)
gauss11=pd.read_csv('lk_point_gauss_1.2.csv')

# %%
gauss1['valid1']=gauss1['mins']<gauss1['conv']

# %%
gauss11['mins']<gauss11['conv']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# dtype: bool

# %%
gauss1= gauss1.truncate(after=102)

# %%
gauss1
# Out:
#      Unnamed: 0  Unnamed: 0.1   had1   had2    z1     z2      mins      maxx  \
# 0             0             0  300.0  200.0  0.25  0.150 -0.017020  0.019712
# 1             1             1  300.0  200.0  0.25  0.222 -0.026259  0.045983
# 2             2             2  300.0  200.0  0.25  0.294 -0.029371  0.069474
# 3             3             3  300.0  200.0  0.25  0.367 -0.028454  0.086042
# 4             4             4  300.0  200.0  0.25  0.439 -0.025728  0.096724
# ..          ...           ...    ...    ...   ...    ...       ...       ...
# 98           98            98  310.0  200.0  0.35  0.728 -0.052829  0.003902
# 99           99            99  310.0  200.0  0.35  0.800 -0.054911  0.004525
# 100         100           100  310.0  200.0  0.45  0.150 -0.012937 -0.004859
# 101         101           101  310.0  200.0  0.45  0.222 -0.025179 -0.009242
# 102         102           102  310.0  200.0  0.45  0.294 -0.034937 -0.012688
#
#      fit_line      conv  valid1
# 0         NaN -0.010766    True
# 1         NaN -0.023279    True
# 2         NaN -0.035372   False
# 3         NaN -0.045260   False
# 4         NaN -0.052982   False
# ..        ...       ...     ...
# 98        NaN  0.004850    True
# 99        NaN  0.006565    True
# 100       NaN -0.007909    True
# 101       NaN -0.014373    True
# 102       NaN -0.018648    True
#
# [103 rows x 11 columns]

# %%
gauss1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'had1', 'had2', 'z1', 'z2', 'mins',
#        'maxx', 'fit_line', 'conv'],
#       dtype='object')

# %%
gauss1 = gauss1.drop('Unnamed: 0',1)
gauss1 = gauss1.drop('Unnamed: 0.1',1)
gauss11 = gauss11.drop('Unnamed: 0',1)
gauss11 = gauss11.drop('Unnamed: 0.1',1)

# %%
#gauss11

# %%
frames = [gauss1,gauss11]
gauss1_tot =pd.concat(frames)
#gauss1_tot=gauss1_tot.drop('Unnamed: 0.1.1',1)
gauss1_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  200.0  0.25  0.150 -0.017020  0.019712       NaN -0.010766
# 1   300.0  200.0  0.25  0.222 -0.026259  0.045983       NaN -0.023279
# 2   300.0  200.0  0.25  0.294 -0.029371  0.069474       NaN -0.035372
# 3   300.0  200.0  0.25  0.367 -0.028454  0.086042       NaN -0.045260
# 4   300.0  200.0  0.25  0.439 -0.025728  0.096724       NaN -0.052982
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.079442 -0.016762       NaN -0.061567
# 53  310.0  205.0  0.60  0.583 -0.083257 -0.017510       NaN -0.064462
# 54  310.0  205.0  0.60  0.656 -0.086589 -0.018139       NaN -0.066976
# 55  310.0  205.0  0.60  0.728 -0.089359 -0.018633       NaN -0.069053
# 56  310.0  205.0  0.60  0.800 -0.091666 -0.019030       NaN -0.070775
#
# [160 rows x 8 columns]

# %%
gauss2=pd.read_csv('lk_point_gauss_2.csv',)
gauss22=pd.read_csv('lk_point_gauss_2.2.csv')

# %%
gauss2 = gauss2.truncate(after=102)

# %%
gauss22
# Out:
#     Unnamed: 0  Unnamed: 0.1   had1   had2    z1     z2      mins      maxx  \
# 0          103           103  310.0  200.0  0.45  0.367 -0.041724 -0.015076
# 1          104           104  310.0  200.0  0.45  0.439 -0.046052 -0.016714
# 2          105           105  310.0  200.0  0.45  0.511 -0.049134 -0.017888
# 3          106           106  310.0  200.0  0.45  0.583 -0.051549 -0.018746
# 4          107           107  310.0  200.0  0.45  0.656 -0.053635 -0.019400
# 5          108           108  310.0  200.0  0.45  0.728 -0.055404 -0.019865
# 6          109           109  310.0  200.0  0.45  0.800 -0.056977 -0.020233
# 7          110           110  310.0  200.0  0.60  0.150 -0.020342 -0.004707
# 8          111           111  310.0  200.0  0.60  0.222 -0.039096 -0.008923
# 9          112           112  310.0  200.0  0.60  0.294 -0.053790 -0.012195
# 10         113           113  310.0  200.0  0.60  0.367 -0.063568 -0.014366
# 11         114           114  310.0  200.0  0.60  0.439 -0.069770 -0.015761
# 12         115           115  310.0  200.0  0.60  0.511 -0.074113 -0.016762
# 13         116           116  310.0  200.0  0.60  0.583 -0.077453 -0.017510
# 14         117           117  310.0  200.0  0.60  0.656 -0.080603 -0.018139
# 15         118           118  310.0  200.0  0.60  0.728 -0.083251 -0.018633
# 16         119           119  310.0  200.0  0.60  0.800 -0.085854 -0.019030
# 17         120           120  310.0  205.0  0.25  0.150 -0.013841  0.004056
# 18         121           121  310.0  205.0  0.25  0.222 -0.029450  0.010218
# 19         122           122  310.0  205.0  0.25  0.294 -0.044358  0.017632
# 20         123           123  310.0  205.0  0.25  0.367 -0.056422  0.025127
# 21         124           124  310.0  205.0  0.25  0.439 -0.065752  0.032036
# 22         125           125  310.0  205.0  0.25  0.511 -0.073947  0.038183
# 23         126           126  310.0  205.0  0.25  0.583 -0.080882  0.043368
# 24         127           127  310.0  205.0  0.25  0.656 -0.086635  0.047619
# 25         128           128  310.0  205.0  0.25  0.728 -0.091782  0.051324
# 26         129           129  310.0  205.0  0.25  0.800 -0.096234  0.054399
# 27         130           130  310.0  205.0  0.35  0.150 -0.009621 -0.002475
# 28         131           131  310.0  205.0  0.35  0.222 -0.019771 -0.004771
# 29         132           132  310.0  205.0  0.35  0.294 -0.028804 -0.005962
# 30         133           133  310.0  205.0  0.35  0.367 -0.035288 -0.005494
# 31         134           134  310.0  205.0  0.35  0.439 -0.040327 -0.003798
# 32         135           135  310.0  205.0  0.35  0.511 -0.044408 -0.002192
# 33         136           136  310.0  205.0  0.35  0.583 -0.047696 -0.000714
# 34         137           137  310.0  205.0  0.35  0.656 -0.050411  0.000474
# 35         138           138  310.0  205.0  0.35  0.728 -0.052829  0.001417
# 36         139           139  310.0  205.0  0.35  0.800 -0.054911  0.002113
# 37         140           140  310.0  205.0  0.45  0.150 -0.012937 -0.004859
# 38         141           141  310.0  205.0  0.45  0.222 -0.025179 -0.009242
# 39         142           142  310.0  205.0  0.45  0.294 -0.035047 -0.012688
# 40         143           143  310.0  205.0  0.45  0.367 -0.041724 -0.015076
# 41         144           144  310.0  205.0  0.45  0.439 -0.046052 -0.016714
# 42         145           145  310.0  205.0  0.45  0.511 -0.049134 -0.017888
# 43         146           146  310.0  205.0  0.45  0.583 -0.051549 -0.018746
# 44         147           147  310.0  205.0  0.45  0.656 -0.053635 -0.019400
# 45         148           148  310.0  205.0  0.45  0.728 -0.055404 -0.019865
# 46         149           149  310.0  205.0  0.45  0.800 -0.056977 -0.020233
# 47         150           150  310.0  205.0  0.60  0.150 -0.020342 -0.004707
# 48         151           151  310.0  205.0  0.60  0.222 -0.039096 -0.008923
# 49         152           152  310.0  205.0  0.60  0.294 -0.053790 -0.012195
# 50         153           153  310.0  205.0  0.60  0.367 -0.063568 -0.014366
# 51         154           154  310.0  205.0  0.60  0.439 -0.069770 -0.015761
# 52         155           155  310.0  205.0  0.60  0.511 -0.074113 -0.016762
# 53         156           156  310.0  205.0  0.60  0.583 -0.077453 -0.017510
# 54         157           157  310.0  205.0  0.60  0.656 -0.080603 -0.018139
# 55         158           158  310.0  205.0  0.60  0.728 -0.083251 -0.018633
# 56         159           159  310.0  205.0  0.60  0.800 -0.085854 -0.019030
#
#     fit_line      conv
# 0        NaN -0.020838
# 1        NaN -0.021692
# 2        NaN -0.021873
# 3        NaN -0.021785
# 4        NaN -0.021646
# 5        NaN -0.021498
# 6        NaN -0.021388
# 7        NaN -0.005475
# 8        NaN -0.009349
# 9        NaN -0.011937
# 10       NaN -0.013509
# 11       NaN -0.014452
# 12       NaN -0.015030
# 13       NaN -0.015323
# 14       NaN -0.015432
# 15       NaN -0.015338
# 16       NaN -0.015153
# 17       NaN -0.010766
# 18       NaN -0.023279
# 19       NaN -0.035372
# 20       NaN -0.045260
# 21       NaN -0.052982
# 22       NaN -0.059190
# 23       NaN -0.064232
# 24       NaN -0.068421
# 25       NaN -0.072171
# 26       NaN -0.075456
# 27       NaN -0.007437
# 28       NaN -0.015651
# 29       NaN -0.022931
# 30       NaN -0.028433
# 31       NaN -0.032422
# 32       NaN -0.035460
# 33       NaN -0.037871
# 34       NaN -0.039858
# 35       NaN -0.041618
# 36       NaN -0.043124
# 37       NaN -0.009879
# 38       NaN -0.019408
# 39       NaN -0.026970
# 40       NaN -0.032062
# 41       NaN -0.035340
# 42       NaN -0.037598
# 43       NaN -0.039289
# 44       NaN -0.040694
# 45       NaN -0.041842
# 46       NaN -0.042845
# 47       NaN -0.016678
# 48       NaN -0.032204
# 49       NaN -0.044441
# 50       NaN -0.052584
# 51       NaN -0.057792
# 52       NaN -0.061567
# 53       NaN -0.064462
# 54       NaN -0.066976
# 55       NaN -0.069053
# 56       NaN -0.070775

# %%
frames = [gauss2,gauss22]
gauss2_tot =pd.concat(frames)
#gauss2_tot=gauss2_tot.drop('Unnamed: 0.1.1',1)
gauss2_tot=gauss2_tot.drop('Unnamed: 0.1',1)
gauss2_tot=gauss2_tot.drop('Unnamed: 0',1)

gauss2_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  200.0  0.25  0.150 -0.016377  0.017127       NaN -0.010766
# 1   300.0  200.0  0.25  0.222 -0.025523  0.040732       NaN -0.023279
# 2   300.0  200.0  0.25  0.294 -0.029588  0.061884       NaN -0.035372
# 3   300.0  200.0  0.25  0.367 -0.029530  0.076870       NaN -0.045260
# 4   300.0  200.0  0.25  0.439 -0.027485  0.086442       NaN -0.052982
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.074113 -0.016762       NaN -0.061567
# 53  310.0  205.0  0.60  0.583 -0.077453 -0.017510       NaN -0.064462
# 54  310.0  205.0  0.60  0.656 -0.080603 -0.018139       NaN -0.066976
# 55  310.0  205.0  0.60  0.728 -0.083251 -0.018633       NaN -0.069053
# 56  310.0  205.0  0.60  0.800 -0.085854 -0.019030       NaN -0.070775
#
# [160 rows x 8 columns]

# %%
gauss3=pd.read_csv('lk_point_gauss_3.csv',)
gauss33=pd.read_csv('lk_point_gauss_3.2.csv')

# %%
gauss3= gauss3.truncate(after=102)

# %%
gauss33
# Out:
#     Unnamed: 0  Unnamed: 0.1   had1   had2    z1     z2      mins      maxx  \
# 0          103           103  310.0  200.0  0.45  0.367 -0.041707 -0.020499
# 1          104           104  310.0  200.0  0.45  0.439 -0.046052 -0.022611
# 2          105           105  310.0  200.0  0.45  0.511 -0.049134 -0.024087
# 3          106           106  310.0  200.0  0.45  0.583 -0.051549 -0.025191
# 4          107           107  310.0  200.0  0.45  0.656 -0.053635 -0.026084
# 5          108           108  310.0  200.0  0.45  0.728 -0.055404 -0.026778
# 6          109           109  310.0  200.0  0.45  0.800 -0.056977 -0.027369
# 7          110           110  310.0  200.0  0.60  0.150 -0.020746 -0.007301
# 8          111           111  310.0  200.0  0.60  0.222 -0.039421 -0.014032
# 9          112           112  310.0  200.0  0.60  0.294 -0.054365 -0.019331
# 10         113           113  310.0  200.0  0.60  0.367 -0.064337 -0.022849
# 11         114           114  310.0  200.0  0.60  0.439 -0.070728 -0.025110
# 12         115           115  310.0  200.0  0.60  0.511 -0.075673 -0.026767
# 13         116           116  310.0  200.0  0.60  0.583 -0.079591 -0.028040
# 14         117           117  310.0  200.0  0.60  0.656 -0.083061 -0.029140
# 15         118           118  310.0  200.0  0.60  0.728 -0.085977 -0.030039
# 16         119           119  310.0  200.0  0.60  0.800 -0.088430 -0.030779
# 17         120           120  310.0  205.0  0.25  0.150 -0.014646  0.006249
# 18         121           121  310.0  205.0  0.25  0.222 -0.029441  0.015241
# 19         122           122  310.0  205.0  0.25  0.294 -0.044356  0.025115
# 20         123           123  310.0  205.0  0.25  0.367 -0.056055  0.034190
# 21         124           124  310.0  205.0  0.25  0.439 -0.065593  0.041983
# 22         125           125  310.0  205.0  0.25  0.511 -0.073947  0.048473
# 23         126           126  310.0  205.0  0.25  0.583 -0.080882  0.053692
# 24         127           127  310.0  205.0  0.25  0.656 -0.086635  0.057807
# 25         128           128  310.0  205.0  0.25  0.728 -0.091782  0.061218
# 26         129           129  310.0  205.0  0.25  0.800 -0.096234  0.063994
# 27         130           130  310.0  205.0  0.35  0.150 -0.009562 -0.001885
# 28         131           131  310.0  205.0  0.35  0.222 -0.019771 -0.003376
# 29         132           132  310.0  205.0  0.35  0.294 -0.028804 -0.003761
# 30         133           133  310.0  205.0  0.35  0.367 -0.035353 -0.002669
# 31         134           134  310.0  205.0  0.35  0.439 -0.040078 -0.001198
# 32         135           135  310.0  205.0  0.35  0.511 -0.044070  0.000427
# 33         136           136  310.0  205.0  0.35  0.583 -0.047283  0.001886
# 34         137           137  310.0  205.0  0.35  0.656 -0.049943  0.003030
# 35         138           138  310.0  205.0  0.35  0.728 -0.052320  0.003902
# 36         139           139  310.0  205.0  0.35  0.800 -0.054360  0.004525
# 37         140           140  310.0  205.0  0.45  0.150 -0.012628 -0.006432
# 38         141           141  310.0  205.0  0.45  0.222 -0.025032 -0.012494
# 39         142           142  310.0  205.0  0.45  0.294 -0.034947 -0.017270
# 40         143           143  310.0  205.0  0.45  0.367 -0.041707 -0.020499
# 41         144           144  310.0  205.0  0.45  0.439 -0.046052 -0.022611
# 42         145           145  310.0  205.0  0.45  0.511 -0.049134 -0.024087
# 43         146           146  310.0  205.0  0.45  0.583 -0.051549 -0.025191
# 44         147           147  310.0  205.0  0.45  0.656 -0.053635 -0.026084
# 45         148           148  310.0  205.0  0.45  0.728 -0.055404 -0.026778
# 46         149           149  310.0  205.0  0.45  0.800 -0.056977 -0.027369
# 47         150           150  310.0  205.0  0.60  0.150 -0.020746 -0.007301
# 48         151           151  310.0  205.0  0.60  0.222 -0.039421 -0.014032
# 49         152           152  310.0  205.0  0.60  0.294 -0.054365 -0.019331
# 50         153           153  310.0  205.0  0.60  0.367 -0.064337 -0.022849
# 51         154           154  310.0  205.0  0.60  0.439 -0.070728 -0.025110
# 52         155           155  310.0  205.0  0.60  0.511 -0.075673 -0.026767
# 53         156           156  310.0  205.0  0.60  0.583 -0.079591 -0.028040
# 54         157           157  310.0  205.0  0.60  0.656 -0.083061 -0.029140
# 55         158           158  310.0  205.0  0.60  0.728 -0.085977 -0.030039
# 56         159           159  310.0  205.0  0.60  0.800 -0.088430 -0.030779
#
#     fit_line      conv
# 0        NaN -0.020838
# 1        NaN -0.021692
# 2        NaN -0.021873
# 3        NaN -0.021785
# 4        NaN -0.021646
# 5        NaN -0.021498
# 6        NaN -0.021388
# 7        NaN -0.005475
# 8        NaN -0.009349
# 9        NaN -0.011937
# 10       NaN -0.013509
# 11       NaN -0.014452
# 12       NaN -0.015030
# 13       NaN -0.015323
# 14       NaN -0.015432
# 15       NaN -0.015338
# 16       NaN -0.015153
# 17       NaN -0.010766
# 18       NaN -0.023279
# 19       NaN -0.035372
# 20       NaN -0.045260
# 21       NaN -0.052982
# 22       NaN -0.059190
# 23       NaN -0.064232
# 24       NaN -0.068421
# 25       NaN -0.072171
# 26       NaN -0.075456
# 27       NaN -0.007437
# 28       NaN -0.015651
# 29       NaN -0.022931
# 30       NaN -0.028433
# 31       NaN -0.032422
# 32       NaN -0.035460
# 33       NaN -0.037871
# 34       NaN -0.039858
# 35       NaN -0.041618
# 36       NaN -0.043124
# 37       NaN -0.009879
# 38       NaN -0.019408
# 39       NaN -0.026970
# 40       NaN -0.032062
# 41       NaN -0.035340
# 42       NaN -0.037598
# 43       NaN -0.039289
# 44       NaN -0.040694
# 45       NaN -0.041842
# 46       NaN -0.042845
# 47       NaN -0.016678
# 48       NaN -0.032204
# 49       NaN -0.044441
# 50       NaN -0.052584
# 51       NaN -0.057792
# 52       NaN -0.061567
# 53       NaN -0.064462
# 54       NaN -0.066976
# 55       NaN -0.069053
# 56       NaN -0.070775

# %%
frames = [gauss3,gauss33]
gauss3_tot =pd.concat(frames)
#gauss3_tot=gauss3_tot.drop('Unnamed: 0.1.1',1)
gauss3_tot=gauss3_tot.drop('Unnamed: 0.1',1)
gauss3_tot=gauss3_tot.drop('Unnamed: 0',1)

gauss3_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  200.0  0.25  0.150 -0.016088  0.019712       NaN -0.010766
# 1   300.0  200.0  0.25  0.222 -0.024118  0.045983       NaN -0.023279
# 2   300.0  200.0  0.25  0.294 -0.026884  0.069474       NaN -0.035372
# 3   300.0  200.0  0.25  0.367 -0.028023  0.086042       NaN -0.045260
# 4   300.0  200.0  0.25  0.439 -0.027230  0.096724       NaN -0.052982
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.075673 -0.026767       NaN -0.061567
# 53  310.0  205.0  0.60  0.583 -0.079591 -0.028040       NaN -0.064462
# 54  310.0  205.0  0.60  0.656 -0.083061 -0.029140       NaN -0.066976
# 55  310.0  205.0  0.60  0.728 -0.085977 -0.030039       NaN -0.069053
# 56  310.0  205.0  0.60  0.800 -0.088430 -0.030779       NaN -0.070775
#
# [160 rows x 8 columns]

# %%
gauss1_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  200.0  0.25  0.150 -0.017020  0.019712       NaN -0.010766
# 1   300.0  200.0  0.25  0.222 -0.026259  0.045983       NaN -0.023279
# 2   300.0  200.0  0.25  0.294 -0.029371  0.069474       NaN -0.035372
# 3   300.0  200.0  0.25  0.367 -0.028454  0.086042       NaN -0.045260
# 4   300.0  200.0  0.25  0.439 -0.025728  0.096724       NaN -0.052982
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.079442 -0.016762       NaN -0.061567
# 53  310.0  205.0  0.60  0.583 -0.083257 -0.017510       NaN -0.064462
# 54  310.0  205.0  0.60  0.656 -0.086589 -0.018139       NaN -0.066976
# 55  310.0  205.0  0.60  0.728 -0.089359 -0.018633       NaN -0.069053
# 56  310.0  205.0  0.60  0.800 -0.091666 -0.019030       NaN -0.070775
#
# [160 rows x 8 columns]

# %%
gauss2_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  200.0  0.25  0.150 -0.016377  0.017127       NaN -0.010766
# 1   300.0  200.0  0.25  0.222 -0.025523  0.040732       NaN -0.023279
# 2   300.0  200.0  0.25  0.294 -0.029588  0.061884       NaN -0.035372
# 3   300.0  200.0  0.25  0.367 -0.029530  0.076870       NaN -0.045260
# 4   300.0  200.0  0.25  0.439 -0.027485  0.086442       NaN -0.052982
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.074113 -0.016762       NaN -0.061567
# 53  310.0  205.0  0.60  0.583 -0.077453 -0.017510       NaN -0.064462
# 54  310.0  205.0  0.60  0.656 -0.080603 -0.018139       NaN -0.066976
# 55  310.0  205.0  0.60  0.728 -0.083251 -0.018633       NaN -0.069053
# 56  310.0  205.0  0.60  0.800 -0.085854 -0.019030       NaN -0.070775
#
# [160 rows x 8 columns]

# %%
gauss3_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  200.0  0.25  0.150 -0.016088  0.019712       NaN -0.010766
# 1   300.0  200.0  0.25  0.222 -0.024118  0.045983       NaN -0.023279
# 2   300.0  200.0  0.25  0.294 -0.026884  0.069474       NaN -0.035372
# 3   300.0  200.0  0.25  0.367 -0.028023  0.086042       NaN -0.045260
# 4   300.0  200.0  0.25  0.439 -0.027230  0.096724       NaN -0.052982
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.075673 -0.026767       NaN -0.061567
# 53  310.0  205.0  0.60  0.583 -0.079591 -0.028040       NaN -0.064462
# 54  310.0  205.0  0.60  0.656 -0.083061 -0.029140       NaN -0.066976
# 55  310.0  205.0  0.60  0.728 -0.085977 -0.030039       NaN -0.069053
# 56  310.0  205.0  0.60  0.800 -0.088430 -0.030779       NaN -0.070775
#
# [160 rows x 8 columns]

# %%
gauss1_tot['mins']>gauss2_tot['mins']
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
#       ...
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# Name: mins, Length: 160, dtype: bool

# %%
new_tot = gauss1_tot

# %%
new_tot=new_tot.drop('mins',1)
new_tot=new_tot.drop('maxx',1)
new_tot=new_tot.drop('fit_line',1)

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv
# 0   300.0  200.0  0.25  0.150 -0.010766
# 1   300.0  200.0  0.25  0.222 -0.023279
# 2   300.0  200.0  0.25  0.294 -0.035372
# 3   300.0  200.0  0.25  0.367 -0.045260
# 4   300.0  200.0  0.25  0.439 -0.052982
# ..    ...    ...   ...    ...       ...
# 52  310.0  205.0  0.60  0.511 -0.061567
# 53  310.0  205.0  0.60  0.583 -0.064462
# 54  310.0  205.0  0.60  0.656 -0.066976
# 55  310.0  205.0  0.60  0.728 -0.069053
# 56  310.0  205.0  0.60  0.800 -0.070775
#
# [160 rows x 5 columns]

# %%
new_tot['valid']=gauss1_tot['mins']<gauss2_tot['mins']

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv  valid
# 0   300.0  200.0  0.25  0.150 -0.010766   True
# 1   300.0  200.0  0.25  0.222 -0.023279   True
# 2   300.0  200.0  0.25  0.294 -0.035372  False
# 3   300.0  200.0  0.25  0.367 -0.045260  False
# 4   300.0  200.0  0.25  0.439 -0.052982  False
# ..    ...    ...   ...    ...       ...    ...
# 52  310.0  205.0  0.60  0.511 -0.061567   True
# 53  310.0  205.0  0.60  0.583 -0.064462   True
# 54  310.0  205.0  0.60  0.656 -0.066976   True
# 55  310.0  205.0  0.60  0.728 -0.069053   True
# 56  310.0  205.0  0.60  0.800 -0.070775   True
#
# [160 rows x 6 columns]

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,min1,min2 in zip(new_tot.valid,gauss1_tot.mins,gauss2_tot.mins):
    if vld == True: mn[i] = min1
    elif vld == False: mn[i] = min2

    i+=1

# %%
new_tot['mins'] = mn

# %%
new_tot=new_tot.drop('valid',1)

# %%
new_tot['valid'] = new_tot['mins']<gauss3_tot['mins']

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins  valid
# 0   300.0  200.0  0.25  0.150 -0.010766 -0.017020   True
# 1   300.0  200.0  0.25  0.222 -0.023279 -0.026259   True
# 2   300.0  200.0  0.25  0.294 -0.035372 -0.029588   True
# 3   300.0  200.0  0.25  0.367 -0.045260 -0.029530   True
# 4   300.0  200.0  0.25  0.439 -0.052982 -0.027485   True
# ..    ...    ...   ...    ...       ...       ...    ...
# 52  310.0  205.0  0.60  0.511 -0.061567 -0.079442   True
# 53  310.0  205.0  0.60  0.583 -0.064462 -0.083257   True
# 54  310.0  205.0  0.60  0.656 -0.066976 -0.086589   True
# 55  310.0  205.0  0.60  0.728 -0.069053 -0.089359   True
# 56  310.0  205.0  0.60  0.800 -0.070775 -0.091666   True
#
# [160 rows x 7 columns]

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,min1,min2 in zip(new_tot.valid,new_tot.mins,gauss3_tot.mins):
    if vld == True: mn[i] = min1
    elif vld == False: mn[i] = min2

    i+=1

# %%
new_tot['mins'] = mn

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins  valid
# 0   300.0  200.0  0.25  0.150 -0.010766 -0.017020   True
# 1   300.0  200.0  0.25  0.222 -0.023279 -0.026259   True
# 2   300.0  200.0  0.25  0.294 -0.035372 -0.029588   True
# 3   300.0  200.0  0.25  0.367 -0.045260 -0.029530   True
# 4   300.0  200.0  0.25  0.439 -0.052982 -0.027485   True
# ..    ...    ...   ...    ...       ...       ...    ...
# 52  310.0  205.0  0.60  0.511 -0.061567 -0.079442   True
# 53  310.0  205.0  0.60  0.583 -0.064462 -0.083257   True
# 54  310.0  205.0  0.60  0.656 -0.066976 -0.086589   True
# 55  310.0  205.0  0.60  0.728 -0.069053 -0.089359   True
# 56  310.0  205.0  0.60  0.800 -0.070775 -0.091666   True
#
# [160 rows x 7 columns]

# %%
new_tot=new_tot.drop('valid',1)

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins
# 0   300.0  200.0  0.25  0.150 -0.010766 -0.017020
# 1   300.0  200.0  0.25  0.222 -0.023279 -0.026259
# 2   300.0  200.0  0.25  0.294 -0.035372 -0.029588
# 3   300.0  200.0  0.25  0.367 -0.045260 -0.029530
# 4   300.0  200.0  0.25  0.439 -0.052982 -0.027485
# ..    ...    ...   ...    ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.061567 -0.079442
# 53  310.0  205.0  0.60  0.583 -0.064462 -0.083257
# 54  310.0  205.0  0.60  0.656 -0.066976 -0.086589
# 55  310.0  205.0  0.60  0.728 -0.069053 -0.089359
# 56  310.0  205.0  0.60  0.800 -0.070775 -0.091666
#
# [160 rows x 6 columns]

# %%
new_tot['valid']=gauss1_tot.maxx>gauss2_tot.maxx

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,max1,max2 in zip(new_tot.valid,gauss1_tot.maxx,gauss2_tot.maxx):
    if vld == True: mn[i] = max1
    elif vld == False: mn[i] = max2

    i+=1

# %%
new_tot['maxx'] = mn

# %%
new_tot=new_tot.drop('valid',1)

# %%
new_tot['valid']=new_tot.maxx>gauss3_tot.maxx

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,max1,max2 in zip(new_tot.valid,new_tot.maxx,gauss3_tot.maxx):
    if vld == True: mn[i] = max1
    elif vld == False: mn[i] = max2

    i+=1

# %%
new_tot['maxx'] = mn

# %%
new_tot=new_tot.drop('valid',1)
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins      maxx
# 0   300.0  200.0  0.25  0.150 -0.010766 -0.017020  0.019712
# 1   300.0  200.0  0.25  0.222 -0.023279 -0.026259  0.045983
# 2   300.0  200.0  0.25  0.294 -0.035372 -0.029588  0.069474
# 3   300.0  200.0  0.25  0.367 -0.045260 -0.029530  0.086042
# 4   300.0  200.0  0.25  0.439 -0.052982 -0.027485  0.096724
# ..    ...    ...   ...    ...       ...       ...       ...
# 52  310.0  205.0  0.60  0.511 -0.061567 -0.079442 -0.016762
# 53  310.0  205.0  0.60  0.583 -0.064462 -0.083257 -0.017510
# 54  310.0  205.0  0.60  0.656 -0.066976 -0.086589 -0.018139
# 55  310.0  205.0  0.60  0.728 -0.069053 -0.089359 -0.018633
# 56  310.0  205.0  0.60  0.800 -0.070775 -0.091666 -0.019030
#
# [160 rows x 7 columns]

# %%
new_tot['valid_min']=new_tot['conv']>new_tot['mins']

# %%
new_tot['valid_max']=new_tot['conv']<new_tot['maxx']

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins      maxx  valid_min  \
# 0   300.0  200.0  0.25  0.150 -0.010766 -0.017020  0.019712       True
# 1   300.0  200.0  0.25  0.222 -0.023279 -0.026259  0.045983       True
# 2   300.0  200.0  0.25  0.294 -0.035372 -0.029588  0.069474      False
# 3   300.0  200.0  0.25  0.367 -0.045260 -0.029530  0.086042      False
# 4   300.0  200.0  0.25  0.439 -0.052982 -0.027485  0.096724      False
# ..    ...    ...   ...    ...       ...       ...       ...        ...
# 52  310.0  205.0  0.60  0.511 -0.061567 -0.079442 -0.016762       True
# 53  310.0  205.0  0.60  0.583 -0.064462 -0.083257 -0.017510       True
# 54  310.0  205.0  0.60  0.656 -0.066976 -0.086589 -0.018139       True
# 55  310.0  205.0  0.60  0.728 -0.069053 -0.089359 -0.018633       True
# 56  310.0  205.0  0.60  0.800 -0.070775 -0.091666 -0.019030       True
#
#     valid_max
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 52       True
# 53       True
# 54       True
# 55       True
# 56       True
#
# [160 rows x 9 columns]

# %%
for i in new_tot.valid_max:
    if i==False :print('yes')
    #else: print('no')
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
for i in new_tot.valid_min:
    if i==False :print('yes')
    #else: print('no')
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
