# %%
import pandas as pd
from numpy import*

# %%
gauss1=pd.read_csv('lp_point_gauss_1.csv',)
gauss11=pd.read_csv('lp_point_gauss_1.2.csv')

# %%
gauss1
# Out:
#      Unnamed: 0  Unnamed: 0.1   had1   had2    z1     z2      mins      maxx  \
# 0             0             0  300.0  100.0  0.25  0.150 -0.021181  0.006177
# 1             1             1  300.0  100.0  0.25  0.222 -0.041093  0.010190
# 2             2             2  300.0  100.0  0.25  0.294 -0.058318  0.011443
# 3             3             3  300.0  100.0  0.25  0.367 -0.071673  0.010466
# 4             4             4  300.0  100.0  0.25  0.439 -0.083004  0.007928
# ..          ...           ...    ...    ...   ...    ...       ...       ...
# 155         155           155  310.0  105.0  0.60  0.511  0.000000  0.000000
# 156         156           156  310.0  105.0  0.60  0.583  0.000000  0.000000
# 157         157           157  310.0  105.0  0.60  0.656  0.000000  0.000000
# 158         158           158  310.0  105.0  0.60  0.728  0.000000  0.000000
# 159         159           159  310.0  105.0  0.60  0.800  0.000000  0.000000
#
#      fit_line      conv
# ...

# %%
gauss11
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   had1   had2    z1     z2  \
# 0          103           103             103  310.0  100.0  0.45  0.367
# 1          104           104             104  310.0  100.0  0.45  0.439
# 2          105           105             105  310.0  100.0  0.45  0.511
# 3          106           106             106  310.0  100.0  0.45  0.583
# 4          107           107             107  310.0  100.0  0.45  0.656
# 5          108           108             108  310.0  100.0  0.45  0.728
# 6          109           109             109  310.0  100.0  0.45  0.800
# 7          110           110             110  310.0  100.0  0.60  0.150
# 8          111           111             111  310.0  100.0  0.60  0.222
# 9          112           112             112  310.0  100.0  0.60  0.294
# 10         113           113             113  310.0  100.0  0.60  0.367
# 11         114           114             114  310.0  100.0  0.60  0.439
# ...

# %%
gauss1= gauss1.truncate(after=102)

# %%
gauss1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'had1', 'had2', 'z1', 'z2', 'mins',
#        'maxx', 'fit_line', 'conv'],
#       dtype='object')

# %%
gauss1 = gauss1.drop('Unnamed: 0',1)
gauss1 = gauss1.drop('Unnamed: 0.1',1)
gauss11 = gauss11.drop('Unnamed: 0',1)
gauss11 = gauss11.drop('Unnamed: 0.1',1)

# %%
#gauss11

# %%
frames = [gauss1,gauss11]
gauss1_tot =pd.concat(frames)
gauss1_tot=gauss1_tot.drop('Unnamed: 0.1.1',1)
gauss1_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  100.0  0.25  0.150 -0.021181  0.006177       NaN -0.013265
# 1   300.0  100.0  0.25  0.222 -0.041093  0.010190       NaN -0.028412
# 2   300.0  100.0  0.25  0.294 -0.058318  0.011443       NaN -0.043223
# 3   300.0  100.0  0.25  0.367 -0.071673  0.010466       NaN -0.056039
# 4   300.0  100.0  0.25  0.439 -0.083004  0.007928       NaN -0.067479
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.061137 -0.029050       NaN -0.051296
# 53  310.0  105.0  0.60  0.583 -0.067236 -0.032748       NaN -0.056289
# 54  310.0  105.0  0.60  0.656 -0.074940 -0.037188       NaN -0.061883
# 55  310.0  105.0  0.60  0.728 -0.085231 -0.043110       NaN -0.069163
# 56  310.0  105.0  0.60  0.800 -0.097087 -0.049978       NaN -0.077397
#
# [160 rows x 8 columns]

# %%
gauss2=pd.read_csv('lp_point_gauss_2.csv',)
gauss22=pd.read_csv('lp_point_gauss_2.2.csv')

# %%
gauss2 = gauss2.truncate(after=102)

# %%
gauss22
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   had1   had2    z1     z2  \
# 0          103           103             103  310.0  100.0  0.45  0.367
# 1          104           104             104  310.0  100.0  0.45  0.439
# 2          105           105             105  310.0  100.0  0.45  0.511
# 3          106           106             106  310.0  100.0  0.45  0.583
# 4          107           107             107  310.0  100.0  0.45  0.656
# 5          108           108             108  310.0  100.0  0.45  0.728
# 6          109           109             109  310.0  100.0  0.45  0.800
# 7          110           110             110  310.0  100.0  0.60  0.150
# 8          111           111             111  310.0  100.0  0.60  0.222
# 9          112           112             112  310.0  100.0  0.60  0.294
# 10         113           113             113  310.0  100.0  0.60  0.367
# 11         114           114             114  310.0  100.0  0.60  0.439
# ...

# %%
frames = [gauss2,gauss22]
gauss2_tot =pd.concat(frames)
gauss2_tot=gauss2_tot.drop('Unnamed: 0.1.1',1)
gauss2_tot=gauss2_tot.drop('Unnamed: 0.1',1)
gauss2_tot=gauss2_tot.drop('Unnamed: 0',1)

gauss2_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  100.0  0.25  0.150 -0.019770  0.006445       NaN -0.013265
# 1   300.0  100.0  0.25  0.222 -0.040008  0.011917       NaN -0.028412
# 2   300.0  100.0  0.25  0.294 -0.057871  0.015051       NaN -0.043223
# 3   300.0  100.0  0.25  0.367 -0.071773  0.015918       NaN -0.056039
# 4   300.0  100.0  0.25  0.439 -0.083847  0.015110       NaN -0.067479
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.059557 -0.032566       NaN -0.051296
# 53  310.0  105.0  0.60  0.583 -0.065453 -0.037181       NaN -0.056289
# 54  310.0  105.0  0.60  0.656 -0.072990 -0.041353       NaN -0.061883
# 55  310.0  105.0  0.60  0.728 -0.083139 -0.045426       NaN -0.069163
# 56  310.0  105.0  0.60  0.800 -0.094853 -0.049876       NaN -0.077397
#
# [160 rows x 8 columns]

# %%
gauss3=pd.read_csv('lp_point_gauss_3.csv',)
gauss33=pd.read_csv('lp_point_gauss_3.2.csv')

# %%
gauss3= gauss3.truncate(after=102)

# %%
gauss33
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   had1   had2    z1     z2  \
# 0          103           103             103  310.0  100.0  0.45  0.367
# 1          104           104             104  310.0  100.0  0.45  0.439
# 2          105           105             105  310.0  100.0  0.45  0.511
# 3          106           106             106  310.0  100.0  0.45  0.583
# 4          107           107             107  310.0  100.0  0.45  0.656
# 5          108           108             108  310.0  100.0  0.45  0.728
# 6          109           109             109  310.0  100.0  0.45  0.800
# 7          110           110             110  310.0  100.0  0.60  0.150
# 8          111           111             111  310.0  100.0  0.60  0.222
# 9          112           112             112  310.0  100.0  0.60  0.294
# 10         113           113             113  310.0  100.0  0.60  0.367
# 11         114           114             114  310.0  100.0  0.60  0.439
# ...

# %%
frames = [gauss3,gauss33]
gauss3_tot =pd.concat(frames)
gauss3_tot=gauss3_tot.drop('Unnamed: 0.1.1',1)
gauss3_tot=gauss3_tot.drop('Unnamed: 0.1',1)
gauss3_tot=gauss3_tot.drop('Unnamed: 0',1)

gauss3_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  100.0  0.25  0.150 -0.020208  0.006445       NaN -0.013265
# 1   300.0  100.0  0.25  0.222 -0.040320  0.011917       NaN -0.028412
# 2   300.0  100.0  0.25  0.294 -0.058767  0.015051       NaN -0.043223
# 3   300.0  100.0  0.25  0.367 -0.073411  0.015918       NaN -0.056039
# 4   300.0  100.0  0.25  0.439 -0.085259  0.015110       NaN -0.067479
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.060012 -0.033846       NaN -0.051296
# 53  310.0  105.0  0.60  0.583 -0.065556 -0.037928       NaN -0.056289
# 54  310.0  105.0  0.60  0.656 -0.073158 -0.041353       NaN -0.061883
# 55  310.0  105.0  0.60  0.728 -0.083474 -0.045426       NaN -0.069163
# 56  310.0  105.0  0.60  0.800 -0.095373 -0.049876       NaN -0.077397
#
# [160 rows x 8 columns]

# %%
gauss1_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  100.0  0.25  0.150 -0.021181  0.006177       NaN -0.013265
# 1   300.0  100.0  0.25  0.222 -0.041093  0.010190       NaN -0.028412
# 2   300.0  100.0  0.25  0.294 -0.058318  0.011443       NaN -0.043223
# 3   300.0  100.0  0.25  0.367 -0.071673  0.010466       NaN -0.056039
# 4   300.0  100.0  0.25  0.439 -0.083004  0.007928       NaN -0.067479
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.061137 -0.029050       NaN -0.051296
# 53  310.0  105.0  0.60  0.583 -0.067236 -0.032748       NaN -0.056289
# 54  310.0  105.0  0.60  0.656 -0.074940 -0.037188       NaN -0.061883
# 55  310.0  105.0  0.60  0.728 -0.085231 -0.043110       NaN -0.069163
# 56  310.0  105.0  0.60  0.800 -0.097087 -0.049978       NaN -0.077397
#
# [160 rows x 8 columns]

# %%
gauss2_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  100.0  0.25  0.150 -0.019770  0.006445       NaN -0.013265
# 1   300.0  100.0  0.25  0.222 -0.040008  0.011917       NaN -0.028412
# 2   300.0  100.0  0.25  0.294 -0.057871  0.015051       NaN -0.043223
# 3   300.0  100.0  0.25  0.367 -0.071773  0.015918       NaN -0.056039
# 4   300.0  100.0  0.25  0.439 -0.083847  0.015110       NaN -0.067479
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.059557 -0.032566       NaN -0.051296
# 53  310.0  105.0  0.60  0.583 -0.065453 -0.037181       NaN -0.056289
# 54  310.0  105.0  0.60  0.656 -0.072990 -0.041353       NaN -0.061883
# 55  310.0  105.0  0.60  0.728 -0.083139 -0.045426       NaN -0.069163
# 56  310.0  105.0  0.60  0.800 -0.094853 -0.049876       NaN -0.077397
#
# [160 rows x 8 columns]

# %%
gauss3_tot
# Out:
#      had1   had2    z1     z2      mins      maxx  fit_line      conv
# 0   300.0  100.0  0.25  0.150 -0.020208  0.006445       NaN -0.013265
# 1   300.0  100.0  0.25  0.222 -0.040320  0.011917       NaN -0.028412
# 2   300.0  100.0  0.25  0.294 -0.058767  0.015051       NaN -0.043223
# 3   300.0  100.0  0.25  0.367 -0.073411  0.015918       NaN -0.056039
# 4   300.0  100.0  0.25  0.439 -0.085259  0.015110       NaN -0.067479
# ..    ...    ...   ...    ...       ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.060012 -0.033846       NaN -0.051296
# 53  310.0  105.0  0.60  0.583 -0.065556 -0.037928       NaN -0.056289
# 54  310.0  105.0  0.60  0.656 -0.073158 -0.041353       NaN -0.061883
# 55  310.0  105.0  0.60  0.728 -0.083474 -0.045426       NaN -0.069163
# 56  310.0  105.0  0.60  0.800 -0.095373 -0.049876       NaN -0.077397
#
# [160 rows x 8 columns]

# %%
gauss1_tot['mins']>gauss2_tot['mins']
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
#       ...
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# Name: mins, Length: 160, dtype: bool

# %%
new_tot = gauss1_tot

# %%
new_tot=new_tot.drop('mins',1)
new_tot=new_tot.drop('maxx',1)
new_tot=new_tot.drop('fit_line',1)

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv
# 0   300.0  100.0  0.25  0.150 -0.013265
# 1   300.0  100.0  0.25  0.222 -0.028412
# 2   300.0  100.0  0.25  0.294 -0.043223
# 3   300.0  100.0  0.25  0.367 -0.056039
# 4   300.0  100.0  0.25  0.439 -0.067479
# ..    ...    ...   ...    ...       ...
# 52  310.0  105.0  0.60  0.511 -0.051296
# 53  310.0  105.0  0.60  0.583 -0.056289
# 54  310.0  105.0  0.60  0.656 -0.061883
# 55  310.0  105.0  0.60  0.728 -0.069163
# 56  310.0  105.0  0.60  0.800 -0.077397
#
# [160 rows x 5 columns]

# %%
new_tot['valid']=gauss1_tot['mins']<gauss2_tot['mins']

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv  valid
# 0   300.0  100.0  0.25  0.150 -0.013265   True
# 1   300.0  100.0  0.25  0.222 -0.028412   True
# 2   300.0  100.0  0.25  0.294 -0.043223   True
# 3   300.0  100.0  0.25  0.367 -0.056039  False
# 4   300.0  100.0  0.25  0.439 -0.067479  False
# ..    ...    ...   ...    ...       ...    ...
# 52  310.0  105.0  0.60  0.511 -0.051296   True
# 53  310.0  105.0  0.60  0.583 -0.056289   True
# 54  310.0  105.0  0.60  0.656 -0.061883   True
# 55  310.0  105.0  0.60  0.728 -0.069163   True
# 56  310.0  105.0  0.60  0.800 -0.077397   True
#
# [160 rows x 6 columns]

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,min1,min2 in zip(new_tot.valid,gauss1_tot.mins,gauss2_tot.mins):
    if vld == True: mn[i] = min1
    elif vld == False: mn[i] = min2

    i+=1

# %%
new_tot['mins'] = mn

# %%
new_tot=new_tot.drop('valid',1)

# %%
new_tot['valid'] = new_tot['mins']<gauss3_tot['mins']

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins  valid
# 0   300.0  100.0  0.25  0.150 -0.013265 -0.021181   True
# 1   300.0  100.0  0.25  0.222 -0.028412 -0.041093   True
# 2   300.0  100.0  0.25  0.294 -0.043223 -0.058318  False
# 3   300.0  100.0  0.25  0.367 -0.056039 -0.071773  False
# 4   300.0  100.0  0.25  0.439 -0.067479 -0.083847  False
# ..    ...    ...   ...    ...       ...       ...    ...
# 52  310.0  105.0  0.60  0.511 -0.051296 -0.061137   True
# 53  310.0  105.0  0.60  0.583 -0.056289 -0.067236   True
# 54  310.0  105.0  0.60  0.656 -0.061883 -0.074940   True
# 55  310.0  105.0  0.60  0.728 -0.069163 -0.085231   True
# 56  310.0  105.0  0.60  0.800 -0.077397 -0.097087   True
#
# [160 rows x 7 columns]

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,min1,min2 in zip(new_tot.valid,new_tot.mins,gauss3_tot.mins):
    if vld == True: mn[i] = min1
    elif vld == False: mn[i] = min2

    i+=1

# %%
new_tot['mins'] = mn

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins  valid
# 0   300.0  100.0  0.25  0.150 -0.013265 -0.021181   True
# 1   300.0  100.0  0.25  0.222 -0.028412 -0.041093   True
# 2   300.0  100.0  0.25  0.294 -0.043223 -0.058767  False
# 3   300.0  100.0  0.25  0.367 -0.056039 -0.073411  False
# 4   300.0  100.0  0.25  0.439 -0.067479 -0.085259  False
# ..    ...    ...   ...    ...       ...       ...    ...
# 52  310.0  105.0  0.60  0.511 -0.051296 -0.061137   True
# 53  310.0  105.0  0.60  0.583 -0.056289 -0.067236   True
# 54  310.0  105.0  0.60  0.656 -0.061883 -0.074940   True
# 55  310.0  105.0  0.60  0.728 -0.069163 -0.085231   True
# 56  310.0  105.0  0.60  0.800 -0.077397 -0.097087   True
#
# [160 rows x 7 columns]

# %%
new_tot=new_tot.drop('valid',1)

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins
# 0   300.0  100.0  0.25  0.150 -0.013265 -0.021181
# 1   300.0  100.0  0.25  0.222 -0.028412 -0.041093
# 2   300.0  100.0  0.25  0.294 -0.043223 -0.058767
# 3   300.0  100.0  0.25  0.367 -0.056039 -0.073411
# 4   300.0  100.0  0.25  0.439 -0.067479 -0.085259
# ..    ...    ...   ...    ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.051296 -0.061137
# 53  310.0  105.0  0.60  0.583 -0.056289 -0.067236
# 54  310.0  105.0  0.60  0.656 -0.061883 -0.074940
# 55  310.0  105.0  0.60  0.728 -0.069163 -0.085231
# 56  310.0  105.0  0.60  0.800 -0.077397 -0.097087
#
# [160 rows x 6 columns]

# %%
new_tot['valid']=gauss1_tot.maxx>gauss2_tot.maxx

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,max1,max2 in zip(new_tot.valid,gauss1_tot.maxx,gauss2_tot.maxx):
    if vld == True: mn[i] = max1
    elif vld == False: mn[i] = max2

    i+=1

# %%
new_tot['maxx'] = mn

# %%
new_tot=new_tot.drop('valid',1)

# %%
new_tot['valid']=new_tot.maxx>gauss3_tot.maxx

# %%
mn = zeros(len(new_tot.valid))
i=0
for vld,max1,max2 in zip(new_tot.valid,new_tot.maxx,gauss3_tot.maxx):
    if vld == True: mn[i] = max1
    elif vld == False: mn[i] = max2

    i+=1

# %%
new_tot['maxx'] = mn

# %%
new_tot=new_tot.drop('valid',1)
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins      maxx
# 0   300.0  100.0  0.25  0.150 -0.013265 -0.021181  0.006445
# 1   300.0  100.0  0.25  0.222 -0.028412 -0.041093  0.011917
# 2   300.0  100.0  0.25  0.294 -0.043223 -0.058767  0.015051
# 3   300.0  100.0  0.25  0.367 -0.056039 -0.073411  0.015918
# 4   300.0  100.0  0.25  0.439 -0.067479 -0.085259  0.015110
# ..    ...    ...   ...    ...       ...       ...       ...
# 52  310.0  105.0  0.60  0.511 -0.051296 -0.061137 -0.029050
# 53  310.0  105.0  0.60  0.583 -0.056289 -0.067236 -0.032748
# 54  310.0  105.0  0.60  0.656 -0.061883 -0.074940 -0.037188
# 55  310.0  105.0  0.60  0.728 -0.069163 -0.085231 -0.043110
# 56  310.0  105.0  0.60  0.800 -0.077397 -0.097087 -0.049876
#
# [160 rows x 7 columns]

# %%
new_tot['conv']>new_tot['mins']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# Length: 160, dtype: bool

# %%
new_tot['conv']<new_tot['maxx']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# Length: 160, dtype: bool

# %%
new_tot['valid_min']=new_tot['conv']>new_tot['mins']

# %%
new_tot['valid_max']=new_tot['conv']<new_tot['maxx']

# %%
new_tot['valid_max']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# Name: valid_max, Length: 160, dtype: bool

# %%
for i in new_tot.valid_max:
    if i==False :print('yes')
    else: print('no')
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no

# %%
for i in new_tot.valid_min:
    if i==False :print('yes')
    #else: print('no')

# %%
new_tot
# Out:
#      had1   had2    z1     z2      conv      mins      maxx  valid_min  \
# 0   300.0  100.0  0.25  0.150 -0.013265 -0.021181  0.006445       True
# 1   300.0  100.0  0.25  0.222 -0.028412 -0.041093  0.011917       True
# 2   300.0  100.0  0.25  0.294 -0.043223 -0.058767  0.015051       True
# 3   300.0  100.0  0.25  0.367 -0.056039 -0.073411  0.015918       True
# 4   300.0  100.0  0.25  0.439 -0.067479 -0.085259  0.015110       True
# ..    ...    ...   ...    ...       ...       ...       ...        ...
# 52  310.0  105.0  0.60  0.511 -0.051296 -0.061137 -0.029050       True
# 53  310.0  105.0  0.60  0.583 -0.056289 -0.067236 -0.032748       True
# 54  310.0  105.0  0.60  0.656 -0.061883 -0.074940 -0.037188       True
# 55  310.0  105.0  0.60  0.728 -0.069163 -0.085231 -0.043110       True
# 56  310.0  105.0  0.60  0.800 -0.077397 -0.097087 -0.049876       True
#
#     valid_max
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# ...

# %%
new_tot.index[new_tot['valid_min'] == False].tolist()
# Out:
# []

# %%
new_tot.index[new_tot['valid_max'] == False].tolist()
# Out:
# []

# %%
new_tot.to_csv('lines_lp_gauss_newtot.csv')
