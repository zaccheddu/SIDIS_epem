# %%
from first_moments import*
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*

# %%
mean2h= array([ 0.09341723, -0.1000179,  -0.11673005, -0.05501322,-0.05501322,-0.05501322,  0.,          0.,
  2.19397263,  0.,0.,0., 3.47205659 , 0., 0. , 2.31910624,2.31910624,2.31910624])

# %%
mean2h=array([ 0.09965859, -0.10666305, -0.1150868 , -0.05767081, -0.05767081, -0.05767081,  0.        ,
         0.        ,  2.11951497,  0.,  0.,  0.        ,  3.50037005,  0.        ,
         0.        ,  2.27198031,  2.27198031,  2.27198031])

# %%
mean1=array( [0.093, -0.100,  -0.117, -0.055,-0.055,-0.055,  0., 0., 2.19,  0.,0.,0.,  3.5,  0., 0., 2.3,2.3,2.3])
mean2=array([ 0.1135492,  -0.11525894, -0.08833732, -0.06032414,-0.06032414,-0.06032414,  0., 0., 0.8659928, 0., 0., 0., 2.59542954, 0.,  0., 0.67835136, 0.67835136,  0.67835136  ])
mean3=array([ 0.08830226, -0.1184549,  -0.06675146, -0.04596938,-0.04596938,-0.04596938,  0.,0.,  0.34150793,  0.,0.,0.,2.2378779, 0.,0.,0.62686554,0.62686554,0.62686554])
mean4=array([ 0.13730469,0.13730469,  -0.13225338, -0.11692807,-0.11692807,-0.07811196,\
              0.,0.,  1.61875805,  0.,0.,0.,\
             2.28736638, 2.28736638, 0.03103877,0.,0., 1.19867128])
mean2h= array([ 0.09341723, -0.1000179,  -0.11673005, -0.05501322,-0.05501322,-0.05501322,  0.,          0.,
  2.19397263,  0.,0.,0., 3.47205659 , 0., 0. , 2.31910624,2.31910624,2.31910624])
mean44=array([ 1.57264335e-01,1.57264335e-01,  -2.05658159e-01, -1.23216970e-01,-1.23216970e-01,-9.67760049e-02,\
              0.,0.,  2.26542241e+00,  0.,0.,0.,\
             2.50659776e+00, 2.50659776e+00, 1.71645791e-03 ,0.,0., 1.16396837e+00])

# %%
         
#[ 1.57264335e-01 -9.67760049e-02 -2.05658159e-01 -1.23216970e-01
#  0.00000000e+00  0.00000000e+00  2.26542241e+00  0.00000000e+00
#  2.50659776e+00  1.16396837e+00  1.71645791e-03  0.00000000e+00
#  8.47440099e-02  0.00000000e+00]

# %%
fst = cr_sec()
zs = linspace(0.25,0.95,100)
qq=10.58
fst.mass=1.115

# %%
fst_moms = array([])
for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

# %%
fst_moms1 = array([])
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms2 = array([])
for z1 in zs:
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms3 = array([])
for z1 in zs:
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms4 = array([])
for z1 in zs:
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms5 = array([])
for z1 in zs:
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
pwd
# Out:
# '/home/zackmrc/Documenti/git_project/plot_opal_primi_momenti/first_moments'

# %%
plot(zlcs,fst_moms)
plot(zlcs,fst_moms1)
plot(zlcs,fst_moms2)
plot(zlcs,fst_moms3)

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[2])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
plot(zlcs,fst_moms)
plot(zlcs,fst_moms1)
plot(zlcs,fst_moms2)
plot(zlcs,fst_moms3)

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[2])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])
plot(zlcs,fst_moms)
plot(zlcs,fst_moms1)
plot(zlcs,fst_moms2)
plot(zlcs,fst_moms3)

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[2])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])
plot(zlcs,fst_moms)
plot(zlcs,fst_moms1)
plot(zlcs,fst_moms2)
plot(zlcs,fst_moms3)

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean4)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean4)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean4)[2])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean4)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean4)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean4)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])
plot(zlcs,fst_moms)
plot(zlcs,fst_moms1)
plot(zlcs,fst_moms2)
plot(zlcs,fst_moms3)

# %%
y_lbl=45
x_lbl =45

lnwd = 3.5


title_s=38 #dimensione titolo bin

fit_l=2.  # dimensione linea fit

t_sz=40
fnt_s=25

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[0])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean44)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='nosu2_nocharm_cut',linewidth=lnwd)
plot(zlcs,fst_moms1,label='nosu2_charm_cut',linewidth=lnwd)
#plot(zlcs,fst_moms2,label='nosu2_charm_nocut',linewidth=lnwd)
plot(zlcs,fst_moms3,label='su2_charm_cut',linewidth=lnwd)
plt.title("up ",fontsize=title_s)
#plt.ylim([-0.0001,None] )
plt.xlim([0.18,0.7] )
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
axhline(linewidth=1.5, ls=':', color='g')

plt.legend(loc='upper right', fontsize=fnt_s,frameon=False)
savefig('0up.pdf')

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[1])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean44)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='nosu2_nocharm_cut',linewidth=lnwd)
plot(zlcs,fst_moms1,label='nosu2_charm_cut',linewidth=lnwd)
#plot(zlcs,fst_moms2,label='nosu2_charm_nocut',linewidth=lnwd)
plot(zlcs,fst_moms3,label='su2_charm_cut',linewidth=lnwd)
plt.title("down",fontsize=title_s)
#plt.ylim([-0.0001,None] )
plt.xlim([0.18,0.7] )
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
axhline(linewidth=1.5, ls=':', color='g')
plt.legend(loc='upper right', fontsize=fnt_s,frameon=False)
savefig('0down.pdf')

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[2])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean44)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='nosu2_nocharm_cut',linewidth=lnwd)
plot(zlcs,fst_moms1,label='nosu2_charm_cut',linewidth=lnwd)
#plot(zlcs,fst_moms2,label='nosu2_charm_nocut',linewidth=lnwd)
plot(zlcs,fst_moms3,label='su2_charm_cut',linewidth=lnwd)
plt.title("strange",fontsize=title_s)
#plt.ylim([-0.0001,None] )
plt.xlim([0.18,0.7] )
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
axhline(linewidth=1.5, ls=':', color='g')
plt.legend(loc='upper right', fontsize=fnt_s,frameon=False)
savefig('0strange.pdf')

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[3])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean44)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='nosu2_nocharm_cut',linewidth=lnwd)
plot(zlcs,fst_moms1,label='nosu2_charm_cut',linewidth=lnwd)
#plot(zlcs,fst_moms2,label='nosu2_charm_nocut',linewidth=lnwd)
plot(zlcs,fst_moms3,label='su2_charm_cut',linewidth=lnwd)
plt.title("up_bar",fontsize=title_s)
#plt.ylim([-0.0001,None] )
plt.xlim([0.18,0.7] )
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
axhline(linewidth=1.5, ls=':', color='g')
plt.legend(loc='lower right', fontsize=fnt_s,frameon=False)
savefig('0up_bar.pdf')

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[4])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean44)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='nosu2_nocharm_cut',linewidth=lnwd)
plot(zlcs,fst_moms1,label='nosu2_charm_cut',linewidth=lnwd)
#plot(zlcs,fst_moms2,label='nosu2_charm_nocut',linewidth=lnwd)
plot(zlcs,fst_moms3,label='su2_charm_cut',linewidth=lnwd)
plt.title("down_bar",fontsize=title_s)
#plt.ylim([-0.0001,None] )
plt.xlim([0.18,0.7] )
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
axhline(linewidth=1.5, ls=':', color='g')
plt.legend(loc='lower right', fontsize=fnt_s,frameon=False)
savefig('0down_bar.pdf')

# %%
fst_moms = array([])
fst_moms1 = array([])
fst_moms2 = array([])
fst_moms3 = array([])
fst_moms4 = array([])
fst_moms5 = array([])

for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean1)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[5])
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean44)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='nosu2_nocharm_cut',linewidth=lnwd)
plot(zlcs,fst_moms1,label='nosu2_charm_cut',linewidth=lnwd)
#plot(zlcs,fst_moms2,label='nosu2_charm_nocut',linewidth=lnwd)
plot(zlcs,fst_moms3,label='su2_charm_cut',linewidth=lnwd)
plt.title("strange_bar",fontsize=title_s)
#plt.ylim([-0.0001,None] )
plt.xlim([0.18,0.7] )
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
axhline(linewidth=1.5, ls=':', color='g')
plt.legend(loc='lower right', fontsize=fnt_s,frameon=False)
savefig('0strange_bar.pdf')
