# %%
from first_moments import*
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*

# %%
pwr1 = pd.read_csv('fit_parameters/fit_hadron_coef_0.25_chi_1.21__True_gk_ll_lgm.csv')
pwr2 = pd.read_csv('fit_parameters/fit_hadron_coef_0.25_chi_1.218__True_gk_ll_lgm.csv')
pwr3 = pd.read_csv('fit_parameters/fit_hadron_coef_0.25_chi_1.437__True_gk_ll_lgm.csv')

# %%
pwr1
# Out:
#         NUP       NDO       NST      NSEA  AUP  ADO       AST  ASEA      BUP  \
# 0  0.099659 -0.106663 -0.115087 -0.057671  0.0  0.0  2.119515   0.0  3.50037
#
#    BDO  BST     BSEA        PP       MSS  coef  chi_sq
# 0  0.0  0.0  2.27198  3.015445  0.348702  0.25    1.21

# %%
pwr2
# Out:
#        NUP       NDO      NST      NSEA  AUP  ADO       AST  ASEA       BUP  \
# 0  0.16542 -0.152615 -0.09244 -0.091276  0.0  0.0  0.686383   0.0  2.864056
#
#    BDO  BST      BSEA        PP       MSS  coef  chi_sq
# 0  0.0  0.0  1.056605  1.867813  0.246021  0.25   1.218

# %%
pwr3
# Out:
#         NUP       NDO       NST     NSEA  AUP  ADO       AST  ASEA       BUP  \
# 0  0.222929 -0.159527 -0.203855 -0.17626  0.0  0.0  2.306557   0.0  2.444924
#
#         BDO       BST  BSEA        PP       MSS  coef  chi_sq
# 0  1.630131  0.058939   0.0  1.928847  0.308942  0.25   1.437

# %%
pwr1.to_numpy()
# Out:
# array([[ 0.09965859, -0.10666305, -0.1150868 , -0.05767081,  0.        ,
#          0.        ,  2.11951497,  0.        ,  3.50037005,  0.        ,
#          0.        ,  2.27198031,  3.01544478,  0.34870161,  0.25      ,
#          1.21      ]])

# %%
mean2h=array([ 0.09965859, -0.10666305, -0.1150868 , -0.05767081, -0.05767081, -0.05767081,  0.        ,
         0.        ,  2.11951497,  0.,  0.,  0.        ,  3.50037005,  0.        ,
         0.        ,  2.27198031,  2.27198031,  2.27198031])

# %%
fst = cr_sec()
zs = linspace(0.25,0.95,100)
qq=10.58
fst.mass=1.115

# %%
fst_moms = array([])
for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[0])  ##up
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

# %%
fst_moms1 = array([])
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[1])  ##down
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms2 = array([])
for z1 in zs:
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[2]) ## strange
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms3 = array([])
for z1 in zs:
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[3])  ##sea
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms4 = array([])
for z1 in zs:
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms5 = array([])
for z1 in zs:
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
y_lbl=45
x_lbl =45

lnwd = 3.5


title_s=38 #dimensione titolo bin

fit_l=2.  # dimensione linea fit

t_sz=35
fnt_s=40

# %%
figure(figsize=(15, 10))
plot(zlcs,fst_moms,label='up',linewidth=lnwd,color='red',linestyle='-')
plot(zlcs,fst_moms1,label='down',linewidth=lnwd,color='blue',linestyle='-.')
plot(zlcs,fst_moms2,label='strange',linewidth=lnwd,color='purple',linestyle='--')
plot(zlcs,fst_moms3+fst_moms4+fst_moms5,label='sea',linewidth=lnwd,color='green',linestyle='dotted')
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
savefig('firs_mom_reference_fit.pdf')
legend(loc='best',fontsize=fnt_s,frameon=False)

# %%
pwr2.to_numpy()
# Out:
# array([[ 0.16542013, -0.15261517, -0.09243986, -0.09127557,  0.        ,
#          0.        ,  0.68638315,  0.        ,  2.86405619,  0.        ,
#          0.        ,  1.05660496,  1.86781338,  0.24602107,  0.25      ,
#          1.218     ]])

# %%
mean2h2 = array([ 0.16542013, -0.15261517, -0.09243986, -0.09127557, -0.09127557, -0.09127557,  0.        ,
         0.        ,  0.68638315,  0.,  0.,  0.        ,  2.86405619,  0.        ,
         0.        ,  1.05660496,  1.05660496 ,  1.05660496  ])

# %%
fst_moms02 = array([])
for z1 in zs:
    fst_moms02= np.append(fst_moms02,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h2)[0])  ##up
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms12 = array([])
for z1 in zs:
    fst_moms12= np.append(fst_moms12,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h2)[1])  ##down
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms22 = array([])
for z1 in zs:
    fst_moms22= np.append(fst_moms22,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h2)[2]) ## strange
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms32 = array([])
for z1 in zs:
    fst_moms32= np.append(fst_moms32,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h2)[3])  ##sea
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms42 = array([])
for z1 in zs:
    fst_moms42= np.append(fst_moms42,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h2)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms52 = array([])
for z1 in zs:
    fst_moms52= np.append(fst_moms52,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h2)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
figure(figsize=(15, 10))
plot(zlcs,fst_moms02,label='up',linewidth=lnwd,color='red',linestyle='-')
plot(zlcs,fst_moms12,label='down',linewidth=lnwd,color='blue',linestyle='-.')
plot(zlcs,fst_moms22,label='strange',linewidth=lnwd,color='purple',linestyle='--')
plot(zlcs,fst_moms32+fst_moms42+fst_moms52,label='sea',linewidth=lnwd,color='green',linestyle='dotted')
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#


legend(loc='best',fontsize=fnt_s,frameon=False)
savefig('firs_mom_reference_fit_charm_nosu2.pdf')

# %%
figure(figsize=(15, 10))
plot(zlcs,fst_moms02,label='up_charm',linewidth=lnwd,color='red',linestyle='-')
plot(zlcs,fst_moms12,label='down_charm',linewidth=lnwd,color='blue',linestyle='-.')
#plot(zlcs,fst_moms22,label='strange_charm',linewidth=lnwd,color='purple',linestyle='--')
#plot(zlcs,fst_moms32+fst_moms42+fst_moms52,label='sea_charm',linewidth=lnwd,color='green',linestyle='dotted')
####
plot(zlcs,fst_moms,label='up',linewidth=lnwd,color='darkred',linestyle='-')
plot(zlcs,fst_moms1,label='down',linewidth=lnwd,color='navy',linestyle='-.')
#plot(zlcs,fst_moms2,label='strange',linewidth=lnwd,color='purple',linestyle='--')
#plot(zlcs,fst_moms3+fst_moms4+fst_moms5,label='sea',linewidth=lnwd,color='green',linestyle='dotted')
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#


legend(loc='best',fontsize=fnt_s,frameon=False)
savefig('firs_mom_compare1.pdf')

# %%
figure(figsize=(15, 10))
#plot(zlcs,fst_moms2,label='up_charm',linewidth=lnwd,color='red',linestyle='-')
#plot(zlcs,fst_moms12,label='down_charm',linewidth=lnwd,color='blue',linestyle='-.')
plot(zlcs,fst_moms22,label='strange_charm',linewidth=lnwd,color='purple',linestyle='--')
plot(zlcs,fst_moms32+fst_moms42+fst_moms52,label='sea_charm',linewidth=lnwd,color='lightgreen',linestyle='-')
####
#plot(zlcs,fst_moms,label='up',linewidth=lnwd,color='darkred',linestyle='-')
#plot(zlcs,fst_moms1,label='down',linewidth=lnwd,color='navy',linestyle='-.')
plot(zlcs,fst_moms2,label='strange',linewidth=lnwd,color='magenta',linestyle='--')
plot(zlcs,fst_moms3+fst_moms4+fst_moms5,label='sea',linewidth=lnwd,color='darkgreen',linestyle='-')
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
legend(loc='best',fontsize=fnt_s,frameon=False)
savefig('firs_mom_compare1.pdf')

# %%
pwr3.to_numpy()
# Out:
# array([[ 0.22292875, -0.15952702, -0.20385527, -0.17626003,  0.        ,
#          0.        ,  2.30655738,  0.        ,  2.44492438,  1.63013126,
#          0.05893878,  0.        ,  1.92884655,  0.30894222,  0.25      ,
#          1.437     ]])

# %%
mean3 =array([ 0.22292875,0.22292875, -0.20385527, -0.17626003,-0.17626003 , -0.15952702,\
         0.,  0.,  2.30655738,  0. ,0.  ,0., \
           2.44492438,2.44492438 ,  0.05893878,  0.,0. ,   1.63013126])

# %%
fst_moms03 = array([])
for z1 in zs:
    fst_moms03= np.append(fst_moms03,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[0])  ##up
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms13 = array([])
for z1 in zs:
    fst_moms13= np.append(fst_moms13,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[1])  ##down
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms23 = array([])
for z1 in zs:
    fst_moms23= np.append(fst_moms23,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[2]) ## strange
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms33 = array([])
for z1 in zs:
    fst_moms33= np.append(fst_moms33,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[3])  ##sea
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms43 = array([])
for z1 in zs:
    fst_moms43= np.append(fst_moms43,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms53 = array([])
for z1 in zs:
    fst_moms53= np.append(fst_moms53,fst.cross_sec2_polda_jk('lbd',z1,qq,mean3)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
figure(figsize=(15, 10))
plot(zlcs,fst_moms03+fst_moms13,label='up+down',linewidth=lnwd,color='red',linestyle='-')
#plot(zlcs,fst_moms23,label='strange',linewidth=lnwd,color='blue',linestyle='-.')
plot(zlcs,fst_moms33+fst_moms43,label='up_bar+down_bar',linewidth=lnwd,color='purple',linestyle='--')
#plot(zlcs,fst_moms53,label='strange_bar',linewidth=lnwd,color='green',linestyle='dotted')
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
legend(loc='best',fontsize=fnt_s,frameon=False)
savefig('firs_mom_charm_si_su2.pdf')

# %%
figure(figsize=(15, 10))
#plot(zlcs,fst_moms03+fst_moms13,label='up+down',linewidth=lnwd,color='red',linestyle='-')
plot(zlcs,fst_moms23,label='strange',linewidth=lnwd,color='blue',linestyle='-.')
#plot(zlcs,fst_moms33+fst_moms43,label='up_bar+down_bar',linewidth=lnwd,color='purple',linestyle='--')
plot(zlcs,fst_moms53,label='strange_bar',linewidth=lnwd,color='green',linestyle='dotted')
plt.tick_params(axis='both', which='major', labelsize=t_sz)
#
plt.xlabel(r'$z$',size=x_lbl)
plt.ylabel(r'$ z\; D^{\bot (1)}_{1T} (z)$',size=y_lbl)
#
legend(loc='best',fontsize=fnt_s,frameon=False)
savefig('firs_mom_charm_si_su2_2.pdf')
