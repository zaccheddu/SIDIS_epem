# %%
from first_moments import*
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*

# %%
mean2h= array([ 0.09341723, -0.1000179,  -0.11673005, -0.05501322,-0.05501322,-0.05501322,  0.,          0.,
  2.19397263,  0.,0.,0., 3.47205659 , 0., 0. , 2.31910624,2.31910624,2.31910624])

# %%
fst = cr_sec()
zs = linspace(0.22,0.95,100)
qq=10.58

# %%
fst_moms = array([])
for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

# %%
fst_moms1 = array([])
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms2 = array([])
for z1 in zs:
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms3 = array([])
for z1 in zs:
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms4 = array([])
for z1 in zs:
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms5 = array([])
for z1 in zs:
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)            
zlcs = array([])
for z1 in zs:
    zlcs= np.append(zlcs,fst.jack(z1)[1])

# %%
pwd
# Out:
# '/home/zackmrc/Documenti/git_project/plot_opal_primi_momenti/first_moments'

# %%
plot(zs,fst_moms)
plot(zs,fst_moms1)
plot(zs,fst_moms2)
plot(zs,fst_moms3)

# %%
df1 = pd.read_csv('fit_parameters/new_bands_/new_gauss_211.csv')
df2 = pd.read_csv('fit_parameters/new_bands_/new_gauss_345.csv')
df3 = pd.read_csv('fit_parameters/new_bands_/new_gauss_3673.csv')
df_gauss = pd.concat([df1,df2,df3])
chi_min = 104.9
df_gauss = df_gauss.loc[(df_gauss['chi']<chi_min+15.79)]

# %%
up_min= array([])
do_min = array([])
st_min = array([])

upb_min = array([])
dob_min = array([])
stb_min = array([])

up_max= array([])
do_max = array([])
st_max = array([])

upb_max = array([])
dob_max = array([])
stb_max = array([])


for z1 in zs:
    up_tmp = array([])
    do_tmp = array([])
    st_tmp = array([])

    upb_tmp = array([])
    dob_tmp = array([])
    stb_tmp = array([])
    for nup, ndo, nst, nsea, ast, bup, bsea in zip(df_gauss.NUP,df_gauss.NDO,df_gauss.NST,df_gauss.NSEA,df_gauss.AST,df_gauss.BUP,df_gauss.BSEA):

        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = ndo#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = f_prm[3] #par[0]      #dob
        f_prm[5] = f_prm[3] # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = 0 #par[0]      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = f_prm[9] #par[0]      #adob
        f_prm[11] = f_prm[9] #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = 0 #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = bsea #par[0]      #bupb
        f_prm[16] = f_prm[15] #par[0]      #bdob
        f_prm[17] = f_prm[15] # par[0]      #bstb
        #print(pt_pp)
        #print(nup)
        #print(fst.cross_sec2_polda('lbd',z1,qq,f_prm)[0])
        up_tmp = np.append(up_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[0])
        do_tmp = np.append(do_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[1])
        st_tmp = np.append(st_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[2])

        upb_tmp = np.append(upb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[3])
        dob_tmp = np.append(dob_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[4])
        stb_tmp = np.append(stb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[5])
        
    up_min= np.append(up_min,min(up_tmp))
    do_min = np.append(do_min,min(do_tmp))
    st_min = np.append(st_min,min(st_tmp))

    upb_min = np.append(upb_min,min(upb_tmp))
    dob_min = np.append(dob_min,min(dob_tmp))
    stb_min = np.append(stb_min,min(stb_tmp))

    up_max= np.append(up_max,max(up_tmp))
    do_max = np.append(do_max,max(do_tmp))
    st_max = np.append(st_max,max(st_tmp))

    upb_max = np.append(upb_max,max(upb_tmp))
    dob_max = np.append(dob_max,max(dob_tmp))
    stb_max = np.append(stb_max,max(stb_tmp))

# %%
a =pd.DataFrame([])

a['UP'] = fst_moms
a['DO'] = fst_moms1
a['ST'] = fst_moms2
a['UPb'] = fst_moms3
a['DOb'] = fst_moms4
a['STb'] = fst_moms5
a['UP_min'] = up_min
a['DO_min'] = do_min
a['ST_min'] = st_min
a['UPb_min'] = upb_min
a['DOb_min'] = dob_min
a['STb_min'] = stb_min

a['UP_max'] = up_max
a['DO_max'] = do_max
a['ST_max'] = st_max
a['UPb_max'] = upb_max
a['DOb_max'] = dob_max
a['STb_max'] = stb_max

a['zs']=zlcs

# %%
a
# Out:
#               UP            DO            ST           UPb           DOb  \
# 0   4.752492e-03 -9.533076e-03 -4.145982e-04 -2.907138e-03 -2.298650e-03
# 1   4.341795e-03 -9.118481e-03 -4.358134e-04 -2.659773e-03 -2.130446e-03
# 2   3.956629e-03 -8.722980e-03 -4.584578e-04 -2.427379e-03 -1.974194e-03
# 3   3.596213e-03 -8.343771e-03 -4.825906e-04 -2.209534e-03 -1.828650e-03
# 4   3.259841e-03 -7.979149e-03 -5.082788e-04 -2.005862e-03 -1.692900e-03
# ..           ...           ...           ...           ...           ...
# 95  1.620882e-11  1.921022e-09 -1.973147e-07 -1.405999e-11  2.366092e-13
# 96  1.351587e-13 -7.323320e-10 -1.021114e-07 -1.189991e-13 -6.529609e-14
# 97 -9.988993e-12 -3.308969e-10 -4.885178e-08  8.940991e-12 -2.062549e-14
# 98  1.558758e-12  2.625021e-10 -2.120172e-08 -1.421262e-12  1.095366e-14
# 99  6.862765e-13  2.895015e-08 -8.122556e-09 -6.390461e-13  7.652149e-13
#
#              STb        UP_min        DO_min        ST_min       UPb_min  \
# 0  -2.373936e-03  2.907918e-03 -1.293563e-02 -8.747042e-04 -4.339694e-03
# 1  -2.249251e-03  2.669374e-03 -1.237306e-02 -8.944957e-04 -3.948699e-03
# 2  -2.136996e-03  2.444358e-03 -1.183640e-02 -9.162259e-04 -3.583770e-03
# 3  -2.035435e-03  2.232568e-03 -1.132184e-02 -9.398651e-04 -3.243943e-03
# 4  -1.943130e-03  2.033743e-03 -1.082708e-02 -9.654032e-04 -2.928329e-03
# ..           ...           ...           ...           ...           ...
# 95 -2.497351e-11  2.663943e-14  1.241243e-09 -3.220280e-07 -6.955056e-10
# 96 -9.193305e-12  1.694966e-16 -9.937168e-10 -1.680201e-07 -7.015922e-12
# 97 -3.021818e-12 -1.753231e-09 -4.490011e-10 -8.103864e-08  2.143688e-14
# 98 -8.629603e-13  1.035315e-15  1.696123e-10 -3.545519e-08 -1.265740e-10
# 99 -2.058705e-13  3.110345e-16  1.870576e-08 -1.369214e-08 -7.293239e-11
#
#          DOb_min       STb_min        UP_max        DO_max        ST_max  \
# 0  -3.431361e-03 -3.543744e-03  6.910801e-03 -6.159671e-03 -1.408469e-04
# 1  -3.162861e-03 -3.339238e-03  6.321686e-03 -5.891786e-03 -1.533554e-04
# 2  -2.914692e-03 -3.155052e-03  5.768340e-03 -5.636238e-03 -1.669124e-04
# 3  -2.684745e-03 -2.988338e-03  5.249745e-03 -5.391217e-03 -1.815939e-04
# 4  -2.471440e-03 -2.836746e-03  4.764992e-03 -5.155622e-03 -1.974820e-04
# ..           ...           ...           ...           ...           ...
# 95  9.413006e-16 -1.235365e-09  1.816089e-09  2.606675e-09 -1.055008e-07
# 96 -3.849711e-12 -5.420166e-10  1.873719e-11 -4.731866e-10 -5.425177e-08
# 97 -1.477063e-12 -2.164028e-10 -9.283308e-15 -2.138047e-10 -2.579204e-08
# 98  1.948734e-17 -7.685307e-11  3.564140e-10  3.561947e-10 -1.112406e-08
# 99  9.694907e-16 -2.349537e-11  2.120097e-10  3.928308e-08 -4.235389e-09
#
#          UPb_max       DOb_max       STb_max        zs
# 0  -1.626771e-03 -1.286275e-03 -1.328403e-03  0.220000
# 1  -1.501586e-03 -1.202752e-03 -1.269824e-03  0.227374
# 2  -1.382690e-03 -1.124546e-03 -1.217282e-03  0.234747
# 3  -1.270010e-03 -1.051083e-03 -1.169940e-03  0.242121
# 4  -1.163497e-03 -9.819637e-04 -1.127109e-03  0.249495
# ..           ...           ...           ...       ...
# 95 -5.593474e-14  1.170435e-11 -9.935190e-14  0.920505
# 96 -3.723155e-16 -2.042935e-16 -2.876332e-14  0.927879
# 97  6.402952e-10 -4.945159e-17 -7.245097e-15  0.935253
# 98 -2.528526e-15  9.755052e-13 -1.535268e-15  0.942626
# 99 -8.096409e-16  8.733165e-11 -2.608281e-16  0.950000
#
# [100 rows x 19 columns]

# %%
a.to_csv('first_moments_2h_new.csv')

# %% [markdown]
# # Power law doppio modello

# %%
df1 = pd.read_csv('fit_parameters/new_bands_/new_pwrlw_211.csv')
df2 = pd.read_csv('fit_parameters/new_bands_/new_pwrlw_345.csv')
df3 = pd.read_csv('fit_parameters/new_bands_/new_pwrlw_3673.csv')
df_gauss = pd.concat([df1,df2,df3])
chi_min = 181.5
df_gauss = df_gauss.loc[(df_gauss['chi']<chi_min+19.99)]

# %%
mean2h= array([ 0.1481, -0.165,  -0.137, -0.0810,  -0.0810,-0.0810,  0.,          0.,
  1.85,  0.,0.,0., 3.438 , 0., 0. , 2.103,2.103,2.103])

# %%
fst_moms = array([])
for z1 in zs:
    fst_moms= np.append(fst_moms,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[0])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
fst_moms1 = array([])
for z1 in zs:
    fst_moms1= np.append(fst_moms1,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[1])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)
    
fst_moms2 = array([])
for z1 in zs:
    fst_moms2= np.append(fst_moms2,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[2])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

fst_moms3 = array([])
for z1 in zs:
    fst_moms3= np.append(fst_moms3,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[3])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
fst_moms4 = array([])
for z1 in zs:
    fst_moms4= np.append(fst_moms4,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[4])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)    
    
fst_moms5 = array([])
for z1 in zs:
    fst_moms5= np.append(fst_moms5,fst.cross_sec2_polda_jk('lbd',z1,qq,mean2h)[5])
    #fst.cross_sec2_polda('lbd',z1,qq,mean)

# %%
plot(zs,fst_moms)
plot(zs,fst_moms1)
plot(zs,fst_moms2)
plot(zs,fst_moms3)

# %%
up_min= array([])
do_min = array([])
st_min = array([])

upb_min = array([])
dob_min = array([])
stb_min = array([])

up_max= array([])
do_max = array([])
st_max = array([])

upb_max = array([])
dob_max = array([])
stb_max = array([])


for z1 in zs:
    up_tmp = array([])
    do_tmp = array([])
    st_tmp = array([])

    upb_tmp = array([])
    dob_tmp = array([])
    stb_tmp = array([])
    for nup, ndo, nst, nsea, ast, bup, bsea in zip(df_gauss.NUP,df_gauss.NDO,df_gauss.NST,df_gauss.NSEA,df_gauss.AST,df_gauss.BUP,df_gauss.BSEA):

        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = ndo#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = f_prm[3] #par[0]      #dob
        f_prm[5] = f_prm[3] # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = 0 #par[0]      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = f_prm[9] #par[0]      #adob
        f_prm[11] = f_prm[9] #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = 0 #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = bsea #par[0]      #bupb
        f_prm[16] = f_prm[15] #par[0]      #bdob
        f_prm[17] = f_prm[15] # par[0]      #bstb
        #print(pt_pp)
        #print(nup)
        #print(fst.cross_sec2_polda('lbd',z1,qq,f_prm)[0])
        up_tmp = np.append(up_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[0])
        do_tmp = np.append(do_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[1])
        st_tmp = np.append(st_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[2])

        upb_tmp = np.append(upb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[3])
        dob_tmp = np.append(dob_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[4])
        stb_tmp = np.append(stb_tmp,fst.cross_sec2_polda_jk('lbd',z1,qq,f_prm)[5])
        
    up_min= np.append(up_min,min(up_tmp))
    do_min = np.append(do_min,min(do_tmp))
    st_min = np.append(st_min,min(st_tmp))

    upb_min = np.append(upb_min,min(upb_tmp))
    dob_min = np.append(dob_min,min(dob_tmp))
    stb_min = np.append(stb_min,min(stb_tmp))

    up_max= np.append(up_max,max(up_tmp))
    do_max = np.append(do_max,max(do_tmp))
    st_max = np.append(st_max,max(st_tmp))

    upb_max = np.append(upb_max,max(upb_tmp))
    dob_max = np.append(dob_max,max(dob_tmp))
    stb_max = np.append(stb_max,max(stb_tmp))

# %%
b =pd.DataFrame([])

b['UP'] = fst_moms
b['DO'] = fst_moms1
b['ST'] = fst_moms2
b['UPb'] = fst_moms3
b['DOb'] = fst_moms4
b['STb'] = fst_moms5
b['UP_min'] = up_min
b['DO_min'] = do_min
b['ST_min'] = st_min
b['UPb_min'] = upb_min
b['DOb_min'] = dob_min
b['STb_min'] = stb_min

b['UP_max'] = up_max
b['DO_max'] = do_max
b['ST_max'] = st_max
b['UPb_max'] = upb_max
b['DOb_max'] = dob_max
b['STb_max'] = stb_max

b['zs']=zs

# %%
b
# Out:
#               UP            DO            ST           UPb           DOb  \
# 0   7.598439e-03 -1.572676e-02 -8.191320e-04 -4.516507e-03 -3.571165e-03
# 1   6.944049e-03 -1.504280e-02 -8.513383e-04 -4.140693e-03 -3.316645e-03
# 2   6.330101e-03 -1.439034e-02 -8.857952e-04 -3.786744e-03 -3.079771e-03
# 3   5.755378e-03 -1.376476e-02 -9.225557e-04 -3.454124e-03 -2.858694e-03
# 4   5.218786e-03 -1.316324e-02 -9.616880e-04 -3.142360e-03 -2.652077e-03
# ..           ...           ...           ...           ...           ...
# 95  2.801110e-11  3.169118e-09 -2.382711e-07 -3.578050e-11  6.021340e-13
# 96  2.343487e-13 -1.208132e-09 -1.229686e-07 -3.092726e-13 -1.697012e-13
# 97 -1.738343e-11 -5.458822e-10 -5.867025e-08  2.378514e-11 -5.486868e-14
# 98  2.723835e-12  4.330510e-10 -2.539425e-08 -3.880984e-12  2.991073e-14
# 99  1.204858e-12  4.775920e-08 -9.702710e-09 -1.797674e-12  2.152594e-12
#
#              STb        UP_min        DO_min        ST_min       UPb_min  \
# 0  -3.688128e-03  7.019283e-03 -1.746000e-02 -1.231182e-03 -4.862144e-03
# 1  -3.501598e-03  6.414792e-03 -1.670066e-02 -1.268791e-03 -4.457714e-03
# 2  -3.333744e-03  5.847655e-03 -1.597629e-02 -1.309358e-03 -4.076799e-03
# 3  -3.181957e-03  5.316752e-03 -1.528176e-02 -1.352898e-03 -3.718823e-03
# 4  -3.044084e-03  4.821070e-03 -1.461395e-02 -1.399450e-03 -3.383280e-03
# ..           ...           ...           ...           ...           ...
# 95 -6.355372e-11  2.547832e-11  2.812990e-09 -2.796762e-07 -4.254530e-11
# 96 -2.389293e-11  2.128914e-13 -1.341279e-09 -1.444395e-07 -3.700367e-13
# 97 -8.038748e-12 -1.901251e-11 -6.060436e-10 -6.896282e-08  2.045532e-11
# 98 -2.356452e-12  2.467147e-12  3.843871e-10 -2.987001e-08 -4.711789e-12
# 99 -5.791256e-13  1.089381e-12  4.239228e-08 -1.142072e-08 -2.201748e-12
#
#          DOb_min       STb_min        UP_max        DO_max        ST_max  \
# 0  -3.844458e-03 -3.970371e-03  8.151259e-03 -1.395947e-02 -5.449175e-04
# 1  -3.570576e-03 -3.769689e-03  7.449810e-03 -1.335237e-02 -5.723029e-04
# 2  -3.315673e-03 -3.589100e-03  6.791652e-03 -1.277323e-02 -6.015322e-04
# 3  -3.077764e-03 -3.425800e-03  6.175489e-03 -1.221795e-02 -6.326795e-04
# 4  -2.855408e-03 -3.277470e-03  5.600154e-03 -1.168403e-02 -6.658294e-04
# ..           ...           ...           ...           ...           ...
# 95  5.232363e-13 -7.556944e-11  3.058731e-11  3.518385e-09 -1.917970e-07
# 96 -2.030431e-13 -2.858727e-11  2.560958e-13 -1.072368e-09 -9.885078e-08
# 97 -6.610240e-14 -9.684587e-12 -1.576983e-11 -4.845390e-10 -4.710034e-08
# 98  2.556662e-14 -2.860899e-12  2.981900e-12  4.807772e-10 -2.035946e-08
# 99  1.827212e-12 -7.092994e-13  1.320422e-12  5.302271e-08 -7.768784e-09
#
#          UPb_max       DOb_max       STb_max        zs
# 0  -4.223998e-03 -3.339880e-03 -3.449268e-03  0.220000
# 1  -3.872862e-03 -3.102116e-03 -3.275106e-03  0.227374
# 2  -3.542121e-03 -2.880818e-03 -3.118385e-03  0.234747
# 3  -3.231276e-03 -2.674262e-03 -2.976669e-03  0.242121
# 4  -2.939892e-03 -2.481199e-03 -2.847948e-03  0.249495
# ..           ...           ...           ...       ...
# 95 -3.109218e-11  7.159758e-13 -5.522627e-11  0.920505
# 96 -2.674295e-13 -1.467414e-13 -2.066033e-11  0.927879
# 97  2.865487e-11 -4.718728e-14 -6.913354e-12  0.935253
# 98 -3.317327e-12  3.631373e-14 -2.014211e-12  0.942626
# 99 -1.525941e-12  2.636446e-12 -4.915861e-13  0.950000
#
# [100 rows x 19 columns]

# %%
b.to_csv('first_moments_double_model_new.csv')
