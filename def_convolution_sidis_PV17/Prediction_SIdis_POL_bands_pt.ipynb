# %%
# -*- coding: utf-8 -*-
from pylab import*
import matplotlib.pyplot as plt
from numpy import*
from matplotlib.pyplot import*
import pandas as pd
import time
import sys
from def_conv_crs_2h import*
from numpy import*
import time 
from datetime import datetime
# Out:
# /home/zackmrc/Documenti/git_project/SIDIS pol/def_convolution_sidis_PV17

# %%
df1 = pd.read_csv('fit_parameters/dfs_/new_gauss_su_charm_no_no.csv') 
df2 = pd.read_csv('fit_parameters/dfs_/new_gauss_su_charm_no_yes.csv')
df3 = pd.read_csv('fit_parameters/dfs_/new_gauss_su_charm_yes_yes.csv')

# %%
chi_min1 = 103.3
chi_min2 = 109.8
chi_min3 = 127.4

df1 = df1.loc[(df1['chi']<chi_min1+15.79)]
df2 = df2.loc[(df2['chi']<chi_min2+17.21)]
df3 = df3.loc[(df3['chi']<chi_min3+15.79)]

# %%
qq = 10.58

pol1 = polarization(0.27)
pol1.g_k = 'PV17'
pol1.mdl_den = 'pwr_lw_star'
pol1.mdl_num = 'gauss'
pol1.scale =qq
pol1.mass = 1.115
pol1.bmax = 0.6
pol1.charm = 'no'


pol2 = polarization(0.27)
pol2.g_k = 'PV17'
pol2.mdl_den = 'pwr_lw_star'
pol2.mdl_num = 'gauss'
pol2.scale =qq
pol2.mass = 1.115
pol2.bmax = 0.6
pol2.charm = 'yes'

pol3 = polarization(0.27)
pol3.g_k = 'PV17'
pol3.mdl_den = 'pwr_lw_star'
pol3.mdl_num = 'gauss'
pol3.scale =qq
pol3.mass = 1.115
pol3.bmax = 0.6
pol3.charm = 'yes'

# %%
f_prm1=arange(0.,18.,1.)
f_prm1[0] = df1['NUP'].mean()
f_prm1[1] = df1['NDO'].mean()#par[0]  #do
f_prm1[2] = df1['NST'].mean()  #par[0]      #st
f_prm1[3] = df1['NSEA'].mean()  #par[0]      #upb
f_prm1[4] = f_prm1[3] #par[0]      #dob
f_prm1[5] = f_prm1[3] # par[0]      #stb
#¯¯¯¯¯¯
f_prm1[6] = 0 #par[0]      #aup
f_prm1[7] = 0 #par[0]      #ado
f_prm1[8] = df1['AST'].mean()  # par[0]      #ast
f_prm1[9] = 0# par[0]      #aupb
f_prm1[10] = f_prm1[9] #par[0]      #adob
f_prm1[11] = f_prm1[9] #par[0]      #astb
#¯#¯¯¯¯¯¯¯
f_prm1[12] = df1['BUP'].mean() #par[0]      #bup
f_prm1[13] = 0 #par[0]      #bdo
f_prm1[14] = 0# par[0]      #bst
f_prm1[15] = df1['BSEA'].mean() #par[0]      #bupb
f_prm1[16] = f_prm1[15] #par[0]      #bdob
f_prm1[17] = f_prm1[15] # par[0]      #bstb
pp1 = np.float64(df1['PP2'].mean())
#pp=gauss.PP.astype(float)

# %%
f_prm2=arange(0.,18.,1.)
f_prm2[0] = df2['NUP'].mean()
f_prm2[1] = df2['NDO'].mean()#par[0]  #do
f_prm2[2] = df2['NST'].mean()  #par[0]      #st
f_prm2[3] = df2['NSEA'].mean()  #par[0]      #upb
f_prm2[4] = f_prm2[3] #par[0]      #dob
f_prm2[5] = f_prm2[3] # par[0]      #stb
#¯¯¯¯¯¯
f_prm2[6] = 0 #par[0]      #aup
f_prm2[7] = df2['ADO'].mean() #par[0]      #ado
f_prm2[8] = df2['AST'].mean()  # par[0]      #ast
f_prm2[9] = 0# par[0]      #aupb
f_prm2[10] = f_prm2[9] #par[0]      #adob
f_prm2[11] = f_prm2[9] #par[0]      #astb
#¯#¯¯¯¯¯¯¯
f_prm2[12] = df2['BUP'].mean() #par[0]      #bup
f_prm2[13] = 0 #par[0]      #bdo
f_prm2[14] = 0# par[0]      #bst
f_prm2[15] = df2['BSEA'].mean() #par[0]      #bupb
f_prm2[16] = f_prm2[15] #par[0]      #bdob
f_prm2[17] = f_prm2[15] # par[0]      #bstb
pp2 = np.float64(df2['PP2'].mean())
#pp=gauss.PP.astype(float)

# %%
f_prm3=arange(0.,18.,1.)
f_prm3[0] = df3['NUP'].mean()
f_prm3[1] = df3['NUP'].mean()#par[0]  #do
f_prm3[2] = df3['NST'].mean()  #par[0]      #st
f_prm3[3] = df3['NSEA'].mean()  #par[0]      #upb
f_prm3[4] = df3['NSEA'].mean()  #par[0]      #dob
f_prm3[5] = df3['NDO'].mean()  # par[0]      #stb
#¯¯¯¯¯¯
f_prm3[6] = 0 #par[0]      #aup
f_prm3[7] = 0.#par[0]      #ado
f_prm3[8] = df3['AST'].mean()  # par[0]      #ast
f_prm3[9] = 0# par[0]      #aupb
f_prm3[10] = 0.#par[0]      #adob
f_prm3[11] = 0 #par[0]      #astb
#¯#¯¯¯¯¯¯¯
f_prm3[12] = df3['BUP'].mean() #par[0]      #bup
f_prm3[13] = df3['BUP'].mean()  #par[0]      #bdo
f_prm3[14] = 0# par[0]      #bst
f_prm3[15] = 0 #par[0]      #bupb
f_prm3[16] = 0 #par[0]      #bdob
f_prm3[17] = df3['BDO'].mean() # par[0]      #bstb
pp3 = np.float64(df3['PP2'].mean())
#pp=gauss.PP.astype(float)

# %%
pts = linspace(0.1,1.1,30)
xb=0.5
zz=0.6

# %%
pls1=zeros(len(pts))
pls2=zeros(len(pts))
pls3=zeros(len(pts))

pls11=zeros(len(pts))
pls22=zeros(len(pts))
pls33=zeros(len(pts))

i=0
for pt in pts:
    pls1[i]= pol1.ratio_pt('lbd','PP',zz,xb,pt,f_prm1,pp1,0.)
    pls2[i]= pol2.ratio_pt('lbd','PP',zz,xb,pt,f_prm2,pp2,0)
    pls3[i]= pol3.ratio_pt('lbd','PP',zz,xb,pt,f_prm3,pp3,0)

    
    pls11[i]= pol1.ratio_pt('lbd_b','PP',zz,xb,pt,f_prm1,pp1,0.)
    pls22[i]= pol2.ratio_pt('lbd_b','PP',zz,xb,pt,f_prm2,pp2,0)
    pls33[i]= pol3.ratio_pt('lbd_b','PP',zz,xb,pt,f_prm3,pp3,0)

    i+=1

# %%
y_lbl=50
x_lbl =50
ers_bar = 2.  # dimensione barre errore
pnt_dat = 9 # dimensione punti

title_s=35 #dimensione titolo bin

fit_l=3.  # dimensione

# %%
fig1, ax = plt.subplots()
plot(pts,pls1*100,label='lambda',linewidth=fit_l)
plot(pts,pls2*100,label='charm_su2no lambda',linewidth=fit_l)
plot(pts,pls3*100,label='charm_su2yes lambda',linewidth=fit_l)
ylabel('Polarization %',size=y_lbl)
xlabel('$p_{\perp}$',size=y_lbl)
plt.text(0.8, -5 ,'$x_b$ = '+ str(xb) , fontsize=title_s)
plt.text(0.8, -10 ,'$z_1$ = '+ str(zz),fontsize=title_s) 
#ylim(-10,35)
tick_params(axis='both', which='major', labelsize=28)
axhline(y = 0., color = 'g', linestyle = 'dotted')
legend(loc='upper right',bbox_to_anchor=(1.,1.), fontsize=20,frameon=True)
fig1.subplots_adjust(top=0.9,bottom=0.2,left=0.230,right=0.76,hspace=0.,wspace=0.)

fig1.set_size_inches(20., 10., forward=True)
fig1.savefig('pol_sidis_PT_lambda_xb_'+str(xb)+'_z1_'+str(zz)+'.pdf')
fig1.savefig('pol_sidis_PT_lambda_xb_'+str(xb)+'_z1_'+str(zz)+'.png')

# %%
fig1, ax = plt.subplots()

plot(pts,pls11*100,label='lambda_bar',linewidth=fit_l)
plot(pts,pls22*100,label='charm_su2no lambda_bar',linewidth=fit_l)
plot(pts,pls33*100,label='charm_su2yes lambda_bar',linewidth=fit_l)
ylabel('Polarization %',size=y_lbl)
xlabel('$p_{\perp}$',size=y_lbl)
plt.text(0.8, -10 ,'$x_b$ = '+ str(xb) , fontsize=title_s)
plt.text(0.8, -15 ,'$z_1$ = '+ str(zz),fontsize=title_s) 

#ylim(-10,35)
tick_params(axis='both', which='major', labelsize=28)
axhline(y = 0., color = 'g', linestyle = 'dotted')
legend(loc='lower right', fontsize=20,frameon=True)
fig1.subplots_adjust(top=0.9,bottom=0.2,left=0.230,right=0.76,hspace=0.,wspace=0.)

fig1.set_size_inches(20., 10., forward=True)
fig1.savefig('pol_sidis_PT_lambda_bar_xb_'+str(xb)+'_z1_'+str(zz)+'.pdf')
fig1.savefig('pol_sidis_PT_lambda_bar_xb_'+str(xb)+'_z1_'+str(zz)+'.png')

# %%
ptss = linspace(0.1,1.1,5)

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)


start = time.time()


mins_lb1 = zeros(len(ptss))
maxx_lb1 = zeros(len(ptss))

mins_lbb1 = zeros(len(ptss))
maxx_lbb1 = zeros(len(ptss))


j=0
for pt in ptss:

    num_tmp1=zeros(len(df1.NUP))
    num_tmp11=zeros(len(df1.NUP))

    i=0
    for nup, ndo, nst, nsea, ast, bup, bsea, pp in zip(df1.NUP,df1.NDO,df1.NST,df1.NSEA,df1.AST,df1.BUP,df1.BSEA,df1.PP2):

     
        
        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = ndo#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = f_prm[3] #par[0]      #dob
        f_prm[5] = f_prm[3] # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = 0 #par[0]      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = f_prm[9] #par[0]      #adob
        f_prm[11] = f_prm[9] #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = 0 #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = bsea #par[0]      #bupb
        f_prm[16] = f_prm[15] #par[0]      #bdob
        f_prm[17] = f_prm[15] # par[0]      #bstb
        pt_pp=pp
        #print(pt_pp)
        #mss = 0# float(df['MSS'])

        num_tmp1[i] = pol1.ratio_pt('lbd','PP',zz,xb,pt,f_prm,pp,0.)
        num_tmp11[i] = pol1.ratio_pt('lbd_b','PP',zz,xb,pt,f_prm,pp,0.)

        i+=1
    mins_lb1[j] = min(num_tmp1)
    maxx_lb1[j] = max(num_tmp1)
    mins_lbb1[j] = min(num_tmp11)
    maxx_lbb1[j] = max(num_tmp11)
    print(mins_lb1)
    j+=1
#dati_lp['mins']	= mins_lp
#dati_lp['maxx']	= maxx_lp
# Out:
# Current Time = 14:34:36
# [-0.01612692  0.          0.          0.          0.        ]
# [-0.01612692 -0.05270114  0.          0.          0.        ]
# [-0.01612692 -0.05270114 -0.078038    0.          0.        ]
# [-0.01612692 -0.05270114 -0.078038   -0.09045928  0.        ]
# [-0.01612692 -0.05270114 -0.078038   -0.09045928 -0.08110834]

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)


start = time.time()


mins_lb2 = zeros(len(ptss))
maxx_lb2 = zeros(len(ptss))

mins_lbb2 = zeros(len(ptss))
maxx_lbb2 = zeros(len(ptss))


j=0
for pt in ptss:

    num_tmp1=zeros(len(df2.NUP))
    num_tmp11=zeros(len(df2.NUP))

    i=0
    for nup, ndo, nst, nsea, ado,ast, bup, bsea, pp in zip(df2.NUP,df2.NDO,df2.NST,df2.NSEA,df2.ADO,df2.AST,df2.BUP,df2.BSEA,df2.PP2):
      
        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = ndo#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = f_prm[3] #par[0]      #dob
        f_prm[5] = f_prm[3] # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = ado #par[0]      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = f_prm[9] #par[0]      #adob
        f_prm[11] = f_prm[9] #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = 0 #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = bsea #par[0]      #bupb
        f_prm[16] = f_prm[15] #par[0]      #bdob
        f_prm[17] = f_prm[15] # par[0]      #bstb
        pt_pp=pp
        #print(pt_pp)
        #mss = 0# float(df['MSS'])

        num_tmp1[i] = pol2.ratio_pt('lbd','PP',zz,xb,pt,f_prm,pp,0.)
        num_tmp11[i] = pol2.ratio_pt('lbd_b','PP',zz,xb,pt,f_prm,pp,0.)

        i+=1
    mins_lb2[j] = min(num_tmp1)
    maxx_lb2[j] = max(num_tmp1)
    mins_lbb2[j] = min(num_tmp11)
    maxx_lbb2[j] = max(num_tmp11)
    print(mins_lb2)
    j+=1
#dati_lp['mins']	= mins_lp
#dati_lp['maxx']	= maxx_lp
# Out:
# Current Time = 14:36:18
# [-0.03256429  0.          0.          0.          0.        ]
# [-0.03256429 -0.10679972  0.          0.          0.        ]
# [-0.03256429 -0.10679972 -0.15920494  0.          0.        ]
# [-0.03256429 -0.10679972 -0.15920494 -0.18224944  0.        ]
# [-0.03256429 -0.10679972 -0.15920494 -0.18224944 -0.15963626]

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)


start = time.time()


mins_lb3 = zeros(len(ptss))
maxx_lb3 = zeros(len(ptss))

mins_lbb3 = zeros(len(ptss))
maxx_lbb3 = zeros(len(ptss))


j=0
for pt in ptss:

    num_tmp1=zeros(len(df3.NUP))
    num_tmp11=zeros(len(df3.NUP))

    i=0
    for nup, ndo, nst, nsea, ast, bup, bdo, pp in zip(df3.NUP,df3.NDO,df3.NST,df3.NSEA,df3.AST,df3.BUP,df3.BDO,df3.PP2):

        f_prm=arange(0.,18.,1.)
        f_prm[0] = nup
        f_prm[1] = nup#par[0]  #do
        f_prm[2] = nst  #par[0]      #st
        f_prm[3] = nsea  #par[0]      #upb
        f_prm[4] = nsea #par[0]      #dob
        f_prm[5] = ndo # par[0]      #stb
        #¯¯¯¯¯¯
        f_prm[6] = 0 #par[0]      #aup
        f_prm[7] = 0.      #ado
        f_prm[8] = ast  # par[0]      #ast
        f_prm[9] = 0# par[0]      #aupb
        f_prm[10] = 0 #par[0]      #adob
        f_prm[11] =0 #par[0]      #astb
        #¯#¯¯¯¯¯¯¯
        f_prm[12] = bup #par[0]      #bup
        f_prm[13] = bup #par[0]      #bdo
        f_prm[14] = 0# par[0]      #bst
        f_prm[15] = 0 #par[0]      #bupb
        f_prm[16] = 0 #par[0]      #bdob
        f_prm[17] = bdo # par[0]      #bstb
        pt_pp=pp
        #print(pt_pp)
        #mss = 0# float(df['MSS'])

        num_tmp1[i] = pol3.ratio_pt('lbd','PP',zz,xb,pt,f_prm,pp,0.)
        num_tmp11[i] = pol3.ratio_pt('lbd_b','PP',zz,xb,pt,f_prm,pp,0.)

        i+=1
    mins_lb3[j] = min(num_tmp1)
    maxx_lb3[j] = max(num_tmp1)
    mins_lbb3[j] = min(num_tmp11)
    maxx_lbb3[j] = max(num_tmp11)
    print(mins_lb3)
    j+=1
#dati_lp['mins']	= mins_lp
#dati_lp['maxx']	= maxx_lp
# Out:
# Current Time = 14:37:08
# [0.00357716 0.         0.         0.         0.        ]
# [0.00357716 0.01164009 0.         0.         0.        ]
# [0.00357716 0.01164009 0.01705544 0.         0.        ]
# [0.00357716 0.01164009 0.01705544 0.01894505 0.        ]
# [0.00357716 0.01164009 0.01705544 0.01894505 0.01660823]

# %%
fig1, ax = plt.subplots()
plot(pts,pls1*100,label='lambda',linewidth=fit_l)
fill_between(ptss,mins_lb1*100,maxx_lb1*100,alpha=0.2)
plot(pts,pls2*100,label='charm_su2no lambda',linewidth=fit_l)
fill_between(ptss,mins_lb2*100,maxx_lb2*100,alpha=0.2)
plot(pts,pls3*100,label='charm_su2yes lambda',linewidth=fit_l)
fill_between(ptss,mins_lb3*100,maxx_lb3*100,alpha=0.2)

ylabel('Polarization %',size=y_lbl)
xlabel('$p_{\perp}$',size=y_lbl)
plt.text(0.8, -5 ,'$x_b$ = '+ str(xb) , fontsize=title_s)
plt.text(0.8, -10 ,'$z_1$ = '+ str(zz),fontsize=title_s) 
#ylim(-10,35)
tick_params(axis='both', which='major', labelsize=28)
axhline(y = 0., color = 'g', linestyle = 'dotted')
legend(loc='upper right',bbox_to_anchor=(1.,1.), fontsize=20,frameon=True)
fig1.subplots_adjust(top=0.9,bottom=0.2,left=0.230,right=0.76,hspace=0.,wspace=0.)

fig1.set_size_inches(20., 10., forward=True)
fig1.savefig('pol_sidis_PT_lambda_xb_'+str(xb)+'_z1_'+str(zz)+'.pdf')
fig1.savefig('pol_sidis_PT_lambda_xb_'+str(xb)+'_z1_'+str(zz)+'.png')

# %%
fig1, ax = plt.subplots()

plot(pts,pls11*100,label='lambda_bar',linewidth=fit_l)
fill_between(ptss,mins_lbb1*100,maxx_lbb1*100,alpha=0.2)
plot(pts,pls22*100,label='charm_su2no lambda_bar',linewidth=fit_l)
fill_between(ptss,mins_lbb2*100,maxx_lbb2*100,alpha=0.2)
plot(pts,pls33*100,label='charm_su2yes lambda_bar',linewidth=fit_l)
fill_between(ptss,mins_lbb3*100,maxx_lbb3*100,alpha=0.2)

ylabel('Polarization %',size=y_lbl)
xlabel('$p_{\perp}$',size=y_lbl)
plt.text(0.8, -10 ,'$x_b$ = '+ str(xb) , fontsize=title_s)
plt.text(0.8, -15 ,'$z_1$ = '+ str(zz),fontsize=title_s) 

#ylim(-10,35)
tick_params(axis='both', which='major', labelsize=28)
axhline(y = 0., color = 'g', linestyle = 'dotted')
legend(loc='lower right', fontsize=20,frameon=True)
fig1.subplots_adjust(top=0.9,bottom=0.2,left=0.230,right=0.76,hspace=0.,wspace=0.)

fig1.set_size_inches(20., 10., forward=True)
fig1.savefig('pol_sidis_PT_lambda_bar_xb_'+str(xb)+'_z1_'+str(zz)+'.pdf')
fig1.savefig('pol_sidis_PT_lambda_bar_xb_'+str(xb)+'_z1_'+str(zz)+'.png')
